# %%
import math
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from torch.distributions.normal import Normal
import matplotlib.pyplot as plt
import time

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

def simulate_paths_multi(S0_vec, r, q_vec, sigma_vec, rho,
                         T, num_steps, N, seed=None):
    """Simulate N correlated GBM paths.  Return (N, num_steps+1, d)."""
    if seed is not None:
        np.random.seed(seed)

    d   = len(S0_vec)
    dt  = T / num_steps

    corr = rho * np.ones((d, d), dtype=np.float32)
    np.fill_diagonal(corr, 1.0)
    L = np.linalg.cholesky(corr)                       # (d,d) Cholesky

    S = np.zeros((N, num_steps + 1, d), dtype=np.float32)
    S[:, 0, :] = S0_vec

    drift  = (r - q_vec - 0.5 * sigma_vec**2) * dt
    vol_dt = sigma_vec * np.sqrt(dt)

    for t in range(num_steps):
        z_corr = np.random.randn(N, d).astype(np.float32) @ L.T
        S[:, t + 1, :] = S[:, t, :] * np.exp(drift + vol_dt * z_corr)

    return S


class ContinuationValueNet(nn.Module):
    """
    Neural network u^theta for continuation value
    """
    def __init__(self, d: int, width: int = None, depth: int = None,
                 negative_slope: float = 0.01, dropout: float = 0.1):
        super().__init__()
        self.d = d
        
        # Normalisation
        self.register_buffer('input_mean', torch.zeros(d + 1))
        self.register_buffer('input_std', torch.ones(d + 1))
        
        # Network
        layers = [nn.Linear(d + 1, width), nn.LeakyReLU(negative_slope)]
        
        for _ in range(depth - 2):
            layers.extend([
                nn.Linear(width, width),
                nn.LeakyReLU(negative_slope)
            ])
        
        layers.append(nn.Linear(width, 1))
        self.net = nn.Sequential(*layers)
        
        # Init weights
        self.apply(self._init_weights)
    
    def _init_weights(self, m):
        if isinstance(m, nn.Linear):
            nn.init.xavier_uniform_(m.weight)
            if m.bias is not None:
                nn.init.constant_(m.bias, 0)
    
    def set_normalization(self, mean, std):
        self.input_mean.copy_(mean)
        self.input_std.copy_(std)
    
    def forward(self, t_norm: torch.Tensor, logS: torch.Tensor) -> torch.Tensor:
        x = torch.cat([t_norm.unsqueeze(-1), logS], dim=-1)
        x = (x - self.input_mean) / (self.input_std + 1e-8)
        return self.net(x).squeeze(-1)


@torch.no_grad()
def evaluate_policy(net, soft_sigma=0.2, N_eval=20_000):
    paths = simulate_paths_multi(S0_vec, r, q_vec, sigma_vec, rho,
                                 T, num_steps, N_eval)
    paths = torch.from_numpy(paths).to(device)
    B     = paths.size(0)

    normal  = Normal(0., 1.)
    survival      = torch.ones(B, device=device)
    total_payoffs = torch.zeros(B, device=device)
    disc_vec      = torch.exp(-r * dt * torch.arange(num_steps, device=device))

    for t in range(num_steps):
        t_norm   = t / num_steps
        S_t      = paths[:, t, :]
        payoff   = torch.clamp(S_t.max(dim=-1).values - K, min=0.)
        payoff_d = payoff * disc_vec[t]

        cont = net(torch.full((B,), t_norm, device=device),
                   torch.log(S_t + 1e-12))
        x    = (payoff_d - cont) / soft_sigma
        p_t  = normal.cdf(x)

        total_payoffs += survival * p_t * payoff_d
        survival       = survival * (1 - p_t)

    S_T     = paths[:, -1, :]
    payoffT = torch.clamp(S_T.max(dim=-1).values - K, min=0.)
    total_payoffs += survival * payoffT * np.exp(-r * T)

    mean = total_payoffs.mean().item()
    se   = total_payoffs.std(unbiased=True).item() / math.sqrt(N_eval)
    return mean, se


@torch.no_grad()
def evaluate_sharp_policy(net, N_eval=20_000, seed_eval=9999):
    net.eval()

    paths = simulate_paths_multi(S0_vec, r, q_vec, sigma_vec, rho,
                                 T, num_steps, N_eval, seed=seed_eval)
    paths = torch.from_numpy(paths).to(device)
    B     = paths.size(0)

    survival      = torch.ones(B, device=device)
    total_payoffs = torch.zeros(B, device=device)
    disc_vec      = torch.exp(-r * dt * torch.arange(num_steps, device=device))

    for t in range(num_steps):
        t_norm   = t / num_steps
        S_t      = paths[:, t, :]
        payoff   = torch.clamp(S_t.max(dim=-1).values - K, min=0.)
        payoff_d = payoff * disc_vec[t]

        cont = net(torch.full((B,), t_norm, device=device),
                   torch.log(S_t + 1e-12))

        exercise = (payoff_d > cont)
        total_payoffs += survival * exercise.float() * payoff_d
        survival       = survival * (~exercise).float()

    S_T     = paths[:, -1, :]
    payoffT = torch.clamp(S_T.max(dim=-1).values - K, min=0.)
    total_payoffs += survival * payoffT * np.exp(-r * T)

    mean = total_payoffs.mean().item()
    se   = total_payoffs.std(unbiased=True).item() / math.sqrt(N_eval)
    return mean, se


class EarlyStopping:
    """
    Early stopping to stop training when improvement small
    """
    
    def __init__(self, patience=20, min_delta=1e-4, relative_threshold=1e-3, 
                 min_epochs=50, max_epochs=2000):
        self.patience = patience
        self.min_delta = min_delta
        self.relative_threshold = relative_threshold
        self.min_epochs = min_epochs
        self.max_epochs = max_epochs
        
        self.best_score = -np.inf
        self.epochs_without_improvement = 0
        self.history = []
        self.start_time = None
        
    def start_training(self):
        self.start_time = time.time()
    
    def get_elapsed_time(self):
        if self.start_time is None:
            return 0
        return time.time() - self.start_time
    
    def format_time(self, seconds):
        hours = int(seconds // 3600)
        minutes = int((seconds % 3600) // 60)
        seconds = int(seconds % 60)
        
        if hours > 0:
            return f"{hours}h {minutes}m {seconds}s"
        elif minutes > 0:
            return f"{minutes}m {seconds}s"
        else:
            return f"{seconds}s"
            
    def should_stop(self, current_score, epoch):
        self.history.append(current_score)
        
        if epoch < self.min_epochs:
            if current_score > self.best_score:
                self.best_score = current_score
                self.epochs_without_improvement = 0
            else:
                self.epochs_without_improvement += 1
            return False
        
        if epoch >= self.max_epochs:
            elapsed_time = self.get_elapsed_time()
            print(f"Maximum epochs ({self.max_epochs}) reached after {self.format_time(elapsed_time)}. Stopping training.")
            return True
        
        absolute_improvement = current_score - self.best_score
        relative_improvement = absolute_improvement / abs(self.best_score) if self.best_score != 0 else 0
        
        is_improvement = (absolute_improvement > self.min_delta and 
                         relative_improvement > self.relative_threshold)
        
        if is_improvement:
            self.best_score = current_score
            self.epochs_without_improvement = 0
            return False
        else:
            self.epochs_without_improvement += 1
            
            if self.epochs_without_improvement >= self.patience:
                elapsed_time = self.get_elapsed_time()
                print(f"Early stopping triggered after {epoch + 1} epochs ({self.format_time(elapsed_time)})")
                print(f"Best score: {self.best_score:.6f}")
                print(f"No improvement for {self.patience} epochs")
                return True
        
        return False
    
    def get_best_score(self):
        return self.best_score
    
    def get_convergence_info(self):
        """
        Return information about the convergence process
        """
        return {
            'best_score': self.best_score,
            'epochs_without_improvement': self.epochs_without_improvement,
            'total_epochs': len(self.history),
            'final_score': self.history[-1] if self.history else None,
            'training_time': self.get_elapsed_time(),
            'training_time_formatted': self.format_time(self.get_elapsed_time())
        }


def train_net(soft_sigma,
              N_train=10_000,
              batch=500,
              lr=0.003,
              seed=None,
              eval_every=10,
              width=None,
              depth=None,
              dropout=0.1,
              curriculum=True,
              # Early stopping parameters
              patience=25,
              min_delta=1e-4,
              relative_threshold=1e-3,
              min_epochs=50,
              max_epochs=2000):
    """
    Train continuation‑value network
    """
    if seed is not None:
        np.random.seed(seed)
        torch.manual_seed(seed)

    net = ContinuationValueNet(d, width=width, depth=depth, dropout=dropout).to(device)
    optimiser = optim.Adam(net.parameters(), lr=lr, weight_decay=1e-4)
    scheduler = optim.lr_scheduler.ReduceLROnPlateau(
        optimiser, mode='max', patience=15, factor=0.5, verbose=True, min_lr=1e-6
    )
    
    # Init early stopping
    early_stopping = EarlyStopping(
        patience=patience,
        min_delta=min_delta,
        relative_threshold=relative_threshold,
        min_epochs=min_epochs,
        max_epochs=max_epochs
    )
    
    normal = Normal(0., 1.)
    disc_vec = torch.exp(-r * dt * torch.arange(num_steps, device=device))

    steps_per_epoch = N_train // batch
    train_hist, eval_hist = [], []
    
    # Input normalization
    print("Setting up input normalization...")
    log_S0 = np.log(S0_vec[0])
    input_mean = torch.tensor([0.5] + [log_S0] * d, device=device)
    input_std = torch.tensor([0.3] + [0.3] * d, device=device)
    net.set_normalization(input_mean, input_std)
    
    if curriculum:
        def get_soft_sigma(ep):
            # Gradually decrease from 2*soft_sigma to soft_sigma over first 200 epochs
            if ep < 200:
                return soft_sigma * (2 - ep / 200)
            return soft_sigma
    else:
        get_soft_sigma = lambda ep: soft_sigma

    print(f"Starting training with early stopping (patience={patience}, min_epochs={min_epochs})")
    print(f"Will stop when improvement < {min_delta:.2e} absolute or < {relative_threshold:.2e} relative")
    
    early_stopping.start_training()
    
    ep = 0
    while True:
        current_soft_sigma = get_soft_sigma(ep)
        epoch_reward_sum = 0.0
        net.train()

        for _ in range(steps_per_epoch):
            S_b = torch.from_numpy(
                simulate_paths_multi(S0_vec, r, q_vec, sigma_vec, rho,
                                     T, num_steps, batch)
            ).to(device)
            B = S_b.size(0)

            logS = torch.log(S_b[:, :num_steps, :] + 1e-12)
            logS_f = logS.reshape(-1, d)
            t_norm = torch.arange(num_steps, device=device).repeat(B) / num_steps
            cont = net(t_norm, logS_f).view(B, num_steps)

            payoff_now = torch.clamp(S_b[:, :num_steps, :].max(dim=-1).values - K, 0.)
            payoff_disc = payoff_now * disc_vec.unsqueeze(0)

            survival = torch.ones(B, device=device)
            total_payoffs = torch.zeros(B, device=device)

            for t in range(num_steps):
                x_t = (payoff_disc[:, t] - cont[:, t]) / current_soft_sigma
                p_t = normal.cdf(x_t)

                total_payoffs += survival * p_t * payoff_disc[:, t]
                survival = survival * (1 - p_t)

            payoff_T = torch.clamp(S_b[:, -1, :].max(dim=-1).values - K, 0.)
            total_payoffs += survival * payoff_T * np.exp(-r * T)

            optimiser.zero_grad()
            loss = -total_payoffs.mean()
            loss.backward()
            
            torch.nn.utils.clip_grad_norm_(net.parameters(), max_norm=1.0)
            optimiser.step()
            epoch_reward_sum += total_payoffs.mean().item()

        avg_reward = epoch_reward_sum / steps_per_epoch
        train_hist.append(avg_reward)
        
        # Evaluation and early stopping check
        if (ep + 1) % eval_every == 0:
            net.eval()
            eval_mean, _ = evaluate_policy(net, current_soft_sigma, N_eval=10_000)
            eval_hist.append((ep + 1, eval_mean))
            
            # Update learning rate scheduler
            scheduler.step(eval_mean)
            
            # Calculate elapsed time
            elapsed_time = early_stopping.get_elapsed_time()
            time_per_epoch = elapsed_time / (ep + 1)
            
            print(f"Epoch {ep + 1:4d} | "
                  f"train‑avg = {avg_reward:8.4f} | "
                  f"soft‑eval = {eval_mean:8.4f} | "
                  f"best = {early_stopping.get_best_score():8.4f} | "
                  f"no_improve = {early_stopping.epochs_without_improvement:2d} | "
                  f"time = {early_stopping.format_time(elapsed_time)} | "
                  f"epoch_time = {time_per_epoch:.1f}s | "
                  f"soft_sigma = {current_soft_sigma:.3f} | "
                  f"lr = {optimiser.param_groups[0]['lr']:.2e}")
            
            # Check for early stopping
            if early_stopping.should_stop(eval_mean, ep + 1):
                break
        else:
            if early_stopping.should_stop(avg_reward, ep + 1):
                break
        
        ep += 1
    
    convergence_info = early_stopping.get_convergence_info()
    print(f"\nTraining completed after {ep + 1} epochs")
    print(f"Total training time: {convergence_info['training_time_formatted']}")
    print(f"Average time per epoch: {convergence_info['training_time'] / (ep + 1):.1f}s")
    print(f"Best evaluation score: {convergence_info['best_score']:.6f}")
    print(f"Final score: {convergence_info['final_score']:.6f}")
    
    return net, train_hist, eval_hist, convergence_info['training_time_formatted']

def average_time_in_seconds(times):
    """
    Helper function for checking training time
    """
    seconds = [float(t.strip('s')) for t in times]   
    avg = sum(seconds) / len(seconds)  
    return round(avg, 1)

# %% [markdown]
# # Option Parameters

# %%
S0_vec       = np.full(d, 100.0, dtype=np.float32)
sigma_vec    = np.full(d, 0.2, dtype=np.float32)
q_vec        = np.full(d, 0.1, dtype=np.float32)
rho          = 0.0
r            = 0.05
K            = 100.0
T            = 3.0
num_steps    = 9
dt           = T / num_steps

# %% [markdown]
# # d = 2

# %%
d = 2
seed = 42

prices = []
times = []
n_trials = 8

for trial in range(n_trials):
    net, train_hist, eval_hist, training_time = train_net(
    soft_sigma=2.0,
    N_train=10_000,
    batch=500,
    lr=0.007,
    seed=seed + trial,
    eval_every=10,
    width=64,
    depth=2,
    dropout=0.1,
    curriculum=False,
    patience=200,            
    min_delta=1e-2,      
    relative_threshold=1e-3,
    min_epochs=50,         
    max_epochs=2000     
    )
    times.append(training_time)

    print("\nEvaluating final policy...")
    sharp_mean, sharp_se = evaluate_sharp_policy(net, N_eval=5_000_000)
    prices.append(sharp_mean)
    print(f"Sharp policy price ≈ {sharp_mean:.4f}  CI: [{sharp_mean - 1.96*sharp_se:.4f},{sharp_mean + 1.96*sharp_se:.4f}] (95% CI)")
# Out:
# Setting up input normalization...
# Starting training with early stopping (patience=200, min_epochs=50)
# Will stop when improvement < 1.00e-02 absolute or < 1.00e-03 relative
# Epoch   10 | train‑avg =  13.6977 | soft‑eval =  13.7763 | best =  13.6522 | no_improve =  0 | time = 0s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch   20 | train‑avg =  13.6729 | soft‑eval =  13.8019 | best =  13.8992 | no_improve =  0 | time = 0s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch   30 | train‑avg =  13.6974 | soft‑eval =  13.8090 | best =  14.0186 | no_improve =  7 | time = 1s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch   40 | train‑avg =  13.7443 | soft‑eval =  13.9459 | best =  14.0599 | no_improve =  4 | time = 1s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch   50 | train‑avg =  13.6540 | soft‑eval =  13.7534 | best =  14.1562 | no_improve =  3 | time = 1s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch   60 | train‑avg =  14.0889 | soft‑eval =  13.8698 | best =  14.1562 | no_improve = 13 | time = 2s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch   70 | train‑avg =  13.6375 | soft‑eval =  13.9691 | best =  14.1562 | no_improve = 23 | time = 2s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch   80 | train‑avg =  14.2061 | soft‑eval =  13.8326 | best =  14.1562 | no_improve = 33 | time = 3s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch   90 | train‑avg =  13.5729 | soft‑eval =  13.6140 | best =  14.1562 | no_improve = 43 | time = 3s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  100 | train‑avg =  13.9312 | soft‑eval =  13.7631 | best =  14.1562 | no_improve = 53 | time = 3s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  110 | train‑avg =  13.7067 | soft‑eval =  14.1413 | best =  14.1562 | no_improve = 63 | time = 4s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  120 | train‑avg =  13.7443 | soft‑eval =  13.8995 | best =  14.1562 | no_improve = 73 | time = 4s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  130 | train‑avg =  13.8993 | soft‑eval =  13.8364 | best =  14.1562 | no_improve = 83 | time = 5s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  140 | train‑avg =  13.8251 | soft‑eval =  13.7533 | best =  14.1562 | no_improve = 93 | time = 5s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  150 | train‑avg =  13.9878 | soft‑eval =  14.0104 | best =  14.1562 | no_improve = 103 | time = 5s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  160 | train‑avg =  13.7166 | soft‑eval =  13.6632 | best =  14.1562 | no_improve = 113 | time = 6s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  170 | train‑avg =  13.7411 | soft‑eval =  13.8557 | best =  14.1562 | no_improve = 123 | time = 6s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  180 | train‑avg =  13.7286 | soft‑eval =  14.0999 | best =  14.1562 | no_improve = 133 | time = 7s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  190 | train‑avg =  13.9772 | soft‑eval =  13.7358 | best =  14.1562 | no_improve = 143 | time = 7s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  200 | train‑avg =  13.8993 | soft‑eval =  13.6966 | best =  14.1562 | no_improve = 153 | time = 7s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  210 | train‑avg =  13.9042 | soft‑eval =  13.7299 | best =  14.1562 | no_improve = 163 | time = 8s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  220 | train‑avg =  13.8441 | soft‑eval =  14.1316 | best =  14.1562 | no_improve = 173 | time = 8s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  230 | train‑avg =  13.8892 | soft‑eval =  13.9932 | best =  14.1562 | no_improve = 183 | time = 9s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  240 | train‑avg =  13.9072 | soft‑eval =  13.9475 | best =  14.1562 | no_improve = 193 | time = 9s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Early stopping triggered after 247 epochs (10s)
# Best score: 14.156185
# No improvement for 200 epochs
#
# Training completed after 246 epochs
# Total training time: 10s
# Average time per epoch: 0.0s
# Best evaluation score: 14.156185
# Final score: 13.821546
#
# Evaluating final policy...
# Sharp policy price ≈ 13.8821  CI: [13.8690,13.8951] (95% CI)
# Setting up input normalization...
# Starting training with early stopping (patience=200, min_epochs=50)
# Will stop when improvement < 1.00e-02 absolute or < 1.00e-03 relative
# Epoch   10 | train‑avg =  13.6375 | soft‑eval =  13.8275 | best =  13.6851 | no_improve =  0 | time = 0s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch   20 | train‑avg =  13.6293 | soft‑eval =  13.8674 | best =  13.8975 | no_improve =  0 | time = 0s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch   30 | train‑avg =  13.6000 | soft‑eval =  13.7381 | best =  14.0513 | no_improve =  3 | time = 1s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch   40 | train‑avg =  13.8357 | soft‑eval =  13.9832 | best =  14.0513 | no_improve = 13 | time = 1s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch   50 | train‑avg =  13.7226 | soft‑eval =  13.9085 | best =  14.0582 | no_improve =  1 | time = 1s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch   60 | train‑avg =  13.8919 | soft‑eval =  14.1237 | best =  14.0582 | no_improve = 11 | time = 2s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch   70 | train‑avg =  13.5101 | soft‑eval =  13.9751 | best =  14.1237 | no_improve =  9 | time = 2s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch   80 | train‑avg =  14.0552 | soft‑eval =  13.9070 | best =  14.1237 | no_improve = 19 | time = 3s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch   90 | train‑avg =  13.9025 | soft‑eval =  13.8684 | best =  14.1568 | no_improve =  7 | time = 3s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  100 | train‑avg =  13.8246 | soft‑eval =  13.8038 | best =  14.1568 | no_improve = 17 | time = 4s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  110 | train‑avg =  13.8293 | soft‑eval =  13.6842 | best =  14.1568 | no_improve = 27 | time = 4s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  120 | train‑avg =  13.9656 | soft‑eval =  14.0508 | best =  14.1568 | no_improve = 37 | time = 4s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  130 | train‑avg =  13.7762 | soft‑eval =  13.7694 | best =  14.1568 | no_improve = 47 | time = 5s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  140 | train‑avg =  13.8850 | soft‑eval =  14.1341 | best =  14.1568 | no_improve = 57 | time = 5s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  150 | train‑avg =  13.6164 | soft‑eval =  13.8167 | best =  14.1568 | no_improve = 67 | time = 5s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  160 | train‑avg =  13.7738 | soft‑eval =  13.4516 | best =  14.1568 | no_improve = 77 | time = 6s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  170 | train‑avg =  13.9690 | soft‑eval =  13.7631 | best =  14.1568 | no_improve = 87 | time = 6s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  180 | train‑avg =  13.8276 | soft‑eval =  13.6433 | best =  14.1568 | no_improve = 97 | time = 7s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  190 | train‑avg =  13.8229 | soft‑eval =  14.0736 | best =  14.1568 | no_improve = 107 | time = 7s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  200 | train‑avg =  13.7410 | soft‑eval =  13.9946 | best =  14.1787 | no_improve =  5 | time = 7s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  210 | train‑avg =  13.7603 | soft‑eval =  13.5853 | best =  14.1787 | no_improve = 15 | time = 8s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  220 | train‑avg =  13.9080 | soft‑eval =  13.9314 | best =  14.1787 | no_improve = 25 | time = 8s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  230 | train‑avg =  13.8850 | soft‑eval =  13.8621 | best =  14.1787 | no_improve = 35 | time = 8s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  240 | train‑avg =  13.9355 | soft‑eval =  13.6117 | best =  14.1787 | no_improve = 45 | time = 9s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  250 | train‑avg =  13.8678 | soft‑eval =  13.7976 | best =  14.1787 | no_improve = 55 | time = 9s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  260 | train‑avg =  14.0017 | soft‑eval =  13.9309 | best =  14.1787 | no_improve = 65 | time = 10s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  270 | train‑avg =  14.0606 | soft‑eval =  14.2142 | best =  14.1787 | no_improve = 75 | time = 10s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  280 | train‑avg =  14.0403 | soft‑eval =  13.8789 | best =  14.2142 | no_improve =  9 | time = 10s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  290 | train‑avg =  13.9957 | soft‑eval =  13.8062 | best =  14.2142 | no_improve = 19 | time = 11s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  300 | train‑avg =  13.9300 | soft‑eval =  14.1990 | best =  14.2142 | no_improve = 29 | time = 11s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  310 | train‑avg =  13.7486 | soft‑eval =  13.9024 | best =  14.2142 | no_improve = 39 | time = 12s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  320 | train‑avg =  13.9788 | soft‑eval =  13.7987 | best =  14.2142 | no_improve = 49 | time = 12s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  330 | train‑avg =  13.6680 | soft‑eval =  13.8910 | best =  14.2142 | no_improve = 59 | time = 13s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  340 | train‑avg =  14.0354 | soft‑eval =  14.1556 | best =  14.2142 | no_improve = 69 | time = 13s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  350 | train‑avg =  13.9840 | soft‑eval =  13.9345 | best =  14.2142 | no_improve = 79 | time = 13s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  360 | train‑avg =  13.7466 | soft‑eval =  13.8783 | best =  14.2142 | no_improve = 89 | time = 14s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  370 | train‑avg =  13.5999 | soft‑eval =  14.0224 | best =  14.2142 | no_improve = 99 | time = 14s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  380 | train‑avg =  13.9073 | soft‑eval =  13.9029 | best =  14.2142 | no_improve = 109 | time = 15s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  390 | train‑avg =  13.7731 | soft‑eval =  13.8041 | best =  14.2767 | no_improve =  1 | time = 15s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  400 | train‑avg =  13.7318 | soft‑eval =  13.9487 | best =  14.2767 | no_improve = 11 | time = 15s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  410 | train‑avg =  13.7447 | soft‑eval =  13.7957 | best =  14.2767 | no_improve = 21 | time = 16s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  420 | train‑avg =  13.9322 | soft‑eval =  14.0129 | best =  14.2767 | no_improve = 31 | time = 16s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  430 | train‑avg =  13.9388 | soft‑eval =  13.7906 | best =  14.2767 | no_improve = 41 | time = 17s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 3.50e-03
# Epoch  440 | train‑avg =  13.9366 | soft‑eval =  14.0015 | best =  14.2767 | no_improve = 51 | time = 17s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 3.50e-03
# Epoch  450 | train‑avg =  13.8673 | soft‑eval =  13.9192 | best =  14.2767 | no_improve = 61 | time = 17s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 3.50e-03
# Epoch  460 | train‑avg =  13.9629 | soft‑eval =  13.7284 | best =  14.2767 | no_improve = 71 | time = 18s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 3.50e-03
# Epoch  470 | train‑avg =  13.6690 | soft‑eval =  14.0335 | best =  14.2767 | no_improve = 81 | time = 18s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 3.50e-03
# Epoch  480 | train‑avg =  13.8552 | soft‑eval =  13.9045 | best =  14.2767 | no_improve = 91 | time = 18s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 3.50e-03
# Epoch  490 | train‑avg =  13.8577 | soft‑eval =  13.7013 | best =  14.2767 | no_improve = 101 | time = 19s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 3.50e-03
# Epoch  500 | train‑avg =  13.9895 | soft‑eval =  14.2882 | best =  14.3351 | no_improve =  4 | time = 19s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 3.50e-03
# Epoch  510 | train‑avg =  13.8797 | soft‑eval =  14.1176 | best =  14.3351 | no_improve = 14 | time = 20s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 3.50e-03
# Epoch  520 | train‑avg =  14.1418 | soft‑eval =  13.9607 | best =  14.3351 | no_improve = 24 | time = 20s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 3.50e-03
# Epoch  530 | train‑avg =  13.7352 | soft‑eval =  13.8856 | best =  14.3351 | no_improve = 34 | time = 20s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 3.50e-03
# Epoch  540 | train‑avg =  13.9624 | soft‑eval =  13.7379 | best =  14.3351 | no_improve = 44 | time = 21s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 3.50e-03
# Epoch  550 | train‑avg =  13.8566 | soft‑eval =  14.0677 | best =  14.3351 | no_improve = 54 | time = 21s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 3.50e-03
# Epoch  560 | train‑avg =  14.0094 | soft‑eval =  13.6578 | best =  14.3351 | no_improve = 64 | time = 22s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 3.50e-03
# Epoch  570 | train‑avg =  13.9103 | soft‑eval =  13.9302 | best =  14.3351 | no_improve = 74 | time = 22s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 3.50e-03
# Epoch  580 | train‑avg =  13.9628 | soft‑eval =  14.0274 | best =  14.3351 | no_improve = 84 | time = 22s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 3.50e-03
# Epoch  590 | train‑avg =  13.9322 | soft‑eval =  13.8443 | best =  14.3667 | no_improve =  1 | time = 23s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 3.50e-03
# Epoch  600 | train‑avg =  13.8601 | soft‑eval =  13.9160 | best =  14.3667 | no_improve = 11 | time = 23s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 3.50e-03
# Epoch  610 | train‑avg =  13.9277 | soft‑eval =  13.9905 | best =  14.3667 | no_improve = 21 | time = 24s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 3.50e-03
# Epoch  620 | train‑avg =  14.0596 | soft‑eval =  13.8017 | best =  14.3667 | no_improve = 31 | time = 24s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 3.50e-03
# Epoch  630 | train‑avg =  13.8382 | soft‑eval =  13.7089 | best =  14.3667 | no_improve = 41 | time = 24s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 3.50e-03
# Epoch  640 | train‑avg =  13.8620 | soft‑eval =  13.6010 | best =  14.3667 | no_improve = 51 | time = 25s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 3.50e-03
# Epoch  650 | train‑avg =  14.0357 | soft‑eval =  13.6772 | best =  14.3667 | no_improve = 61 | time = 25s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 3.50e-03
# Epoch  660 | train‑avg =  13.6731 | soft‑eval =  14.0482 | best =  14.3667 | no_improve = 71 | time = 26s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 1.75e-03
# Epoch  670 | train‑avg =  13.9703 | soft‑eval =  13.7681 | best =  14.3667 | no_improve = 81 | time = 26s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 1.75e-03
# Epoch  680 | train‑avg =  13.7713 | soft‑eval =  14.0471 | best =  14.3667 | no_improve = 91 | time = 26s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 1.75e-03
# Epoch  690 | train‑avg =  13.8282 | soft‑eval =  14.1245 | best =  14.3667 | no_improve = 101 | time = 27s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 1.75e-03
# Epoch  700 | train‑avg =  13.9039 | soft‑eval =  13.7040 | best =  14.3667 | no_improve = 111 | time = 27s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 1.75e-03
# Epoch  710 | train‑avg =  13.7459 | soft‑eval =  13.9536 | best =  14.3667 | no_improve = 121 | time = 28s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 1.75e-03
# Epoch  720 | train‑avg =  14.0759 | soft‑eval =  13.9047 | best =  14.3667 | no_improve = 131 | time = 28s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 1.75e-03
# Epoch  730 | train‑avg =  13.9208 | soft‑eval =  13.9045 | best =  14.3667 | no_improve = 141 | time = 28s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 1.75e-03
# Epoch  740 | train‑avg =  13.6598 | soft‑eval =  13.9188 | best =  14.3667 | no_improve = 151 | time = 29s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 1.75e-03
# Epoch  750 | train‑avg =  13.9888 | soft‑eval =  13.7407 | best =  14.3667 | no_improve = 161 | time = 29s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 1.75e-03
# Epoch  760 | train‑avg =  13.5237 | soft‑eval =  13.9634 | best =  14.3667 | no_improve = 171 | time = 30s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 1.75e-03
# Epoch  770 | train‑avg =  13.8846 | soft‑eval =  13.9089 | best =  14.3667 | no_improve = 181 | time = 30s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 1.75e-03
# Epoch  780 | train‑avg =  13.8423 | soft‑eval =  13.6969 | best =  14.3667 | no_improve = 191 | time = 31s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 1.75e-03
# Early stopping triggered after 789 epochs (31s)
# Best score: 14.366689
# No improvement for 200 epochs
#
# Training completed after 788 epochs
# Total training time: 31s
# Average time per epoch: 0.0s
# Best evaluation score: 14.366689
# Final score: 13.860549
#
# Evaluating final policy...
# Sharp policy price ≈ 13.8919  CI: [13.8787,13.9051] (95% CI)
# Setting up input normalization...
# Starting training with early stopping (patience=200, min_epochs=50)
# Will stop when improvement < 1.00e-02 absolute or < 1.00e-03 relative
# Epoch   10 | train‑avg =  13.6274 | soft‑eval =  13.6773 | best =  13.5858 | no_improve =  2 | time = 0s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch   20 | train‑avg =  13.8376 | soft‑eval =  14.0250 | best =  13.9816 | no_improve =  8 | time = 0s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch   30 | train‑avg =  13.9073 | soft‑eval =  13.7828 | best =  14.0344 | no_improve =  7 | time = 1s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch   40 | train‑avg =  13.7584 | soft‑eval =  13.9019 | best =  14.2321 | no_improve =  2 | time = 1s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch   50 | train‑avg =  13.7983 | soft‑eval =  14.1463 | best =  14.2321 | no_improve = 12 | time = 1s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch   60 | train‑avg =  13.6107 | soft‑eval =  13.8998 | best =  14.3058 | no_improve =  1 | time = 2s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch   70 | train‑avg =  13.9721 | soft‑eval =  13.8933 | best =  14.3058 | no_improve = 11 | time = 2s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch   80 | train‑avg =  14.0700 | soft‑eval =  13.8971 | best =  14.3411 | no_improve =  4 | time = 3s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch   90 | train‑avg =  13.9632 | soft‑eval =  13.7468 | best =  14.3411 | no_improve = 14 | time = 3s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  100 | train‑avg =  13.8935 | soft‑eval =  14.1013 | best =  14.3411 | no_improve = 24 | time = 3s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  110 | train‑avg =  13.7562 | soft‑eval =  14.0707 | best =  14.3411 | no_improve = 34 | time = 4s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  120 | train‑avg =  13.6063 | soft‑eval =  13.7085 | best =  14.3411 | no_improve = 44 | time = 4s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  130 | train‑avg =  13.7599 | soft‑eval =  14.0264 | best =  14.3411 | no_improve = 54 | time = 5s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  140 | train‑avg =  14.0389 | soft‑eval =  13.8553 | best =  14.3411 | no_improve = 64 | time = 5s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  150 | train‑avg =  13.6537 | soft‑eval =  13.7599 | best =  14.3411 | no_improve = 74 | time = 5s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  160 | train‑avg =  13.4611 | soft‑eval =  13.7820 | best =  14.3411 | no_improve = 84 | time = 6s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  170 | train‑avg =  13.8273 | soft‑eval =  13.8554 | best =  14.3411 | no_improve = 94 | time = 6s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  180 | train‑avg =  13.6919 | soft‑eval =  13.8500 | best =  14.3411 | no_improve = 104 | time = 7s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  190 | train‑avg =  13.7831 | soft‑eval =  13.8389 | best =  14.3411 | no_improve = 114 | time = 7s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  200 | train‑avg =  13.7818 | soft‑eval =  13.9450 | best =  14.3411 | no_improve = 124 | time = 8s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  210 | train‑avg =  13.7106 | soft‑eval =  13.9146 | best =  14.3411 | no_improve = 134 | time = 8s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 3.50e-03
# Epoch  220 | train‑avg =  13.9471 | soft‑eval =  14.0103 | best =  14.3411 | no_improve = 144 | time = 8s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 3.50e-03
# Epoch  230 | train‑avg =  13.7602 | soft‑eval =  13.9312 | best =  14.3411 | no_improve = 154 | time = 9s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 3.50e-03
# Epoch  240 | train‑avg =  13.6704 | soft‑eval =  14.0830 | best =  14.3411 | no_improve = 164 | time = 9s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 3.50e-03
# Epoch  250 | train‑avg =  13.9723 | soft‑eval =  13.7073 | best =  14.3411 | no_improve = 174 | time = 10s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 3.50e-03
# Epoch  260 | train‑avg =  13.9869 | soft‑eval =  13.9058 | best =  14.3411 | no_improve = 184 | time = 10s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 3.50e-03
# Epoch  270 | train‑avg =  13.8671 | soft‑eval =  14.0070 | best =  14.3411 | no_improve = 194 | time = 11s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 3.50e-03
# Early stopping triggered after 276 epochs (11s)
# Best score: 14.341108
# No improvement for 200 epochs
#
# Training completed after 275 epochs
# Total training time: 11s
# Average time per epoch: 0.0s
# Best evaluation score: 14.341108
# Final score: 13.761868
#
# Evaluating final policy...
# Sharp policy price ≈ 13.8827  CI: [13.8692,13.8962] (95% CI)
# Setting up input normalization...
# Starting training with early stopping (patience=200, min_epochs=50)
# Will stop when improvement < 1.00e-02 absolute or < 1.00e-03 relative
# Epoch   10 | train‑avg =  13.7054 | soft‑eval =  13.7431 | best =  13.9165 | no_improve =  0 | time = 0s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch   20 | train‑avg =  13.6648 | soft‑eval =  13.7492 | best =  13.9899 | no_improve =  2 | time = 0s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch   30 | train‑avg =  13.9110 | soft‑eval =  13.9156 | best =  13.9899 | no_improve = 12 | time = 1s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch   40 | train‑avg =  13.6324 | soft‑eval =  13.9625 | best =  14.0761 | no_improve =  0 | time = 1s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch   50 | train‑avg =  13.9625 | soft‑eval =  13.8532 | best =  14.0761 | no_improve = 10 | time = 1s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch   60 | train‑avg =  13.7327 | soft‑eval =  13.6809 | best =  14.0761 | no_improve = 20 | time = 2s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch   70 | train‑avg =  13.6742 | soft‑eval =  13.7030 | best =  14.1308 | no_improve =  4 | time = 2s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch   80 | train‑avg =  13.8403 | soft‑eval =  13.9895 | best =  14.1308 | no_improve = 14 | time = 3s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch   90 | train‑avg =  13.6885 | soft‑eval =  13.8314 | best =  14.1308 | no_improve = 24 | time = 3s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  100 | train‑avg =  13.8096 | soft‑eval =  13.6800 | best =  14.1308 | no_improve = 34 | time = 3s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  110 | train‑avg =  13.8082 | soft‑eval =  13.7110 | best =  14.2158 | no_improve =  2 | time = 4s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  120 | train‑avg =  13.6516 | soft‑eval =  13.8909 | best =  14.2158 | no_improve = 12 | time = 4s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  130 | train‑avg =  13.8576 | soft‑eval =  13.7745 | best =  14.2158 | no_improve = 22 | time = 5s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  140 | train‑avg =  13.7245 | soft‑eval =  13.6754 | best =  14.2158 | no_improve = 32 | time = 5s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  150 | train‑avg =  13.8507 | soft‑eval =  13.7057 | best =  14.2158 | no_improve = 42 | time = 5s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  160 | train‑avg =  13.9739 | soft‑eval =  13.7004 | best =  14.2158 | no_improve = 52 | time = 6s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  170 | train‑avg =  13.6427 | soft‑eval =  14.0016 | best =  14.2158 | no_improve = 62 | time = 6s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  180 | train‑avg =  13.5985 | soft‑eval =  13.8847 | best =  14.2158 | no_improve = 72 | time = 6s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  190 | train‑avg =  13.8884 | soft‑eval =  13.8417 | best =  14.2158 | no_improve = 82 | time = 7s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  200 | train‑avg =  13.7943 | soft‑eval =  13.9659 | best =  14.2158 | no_improve = 92 | time = 7s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  210 | train‑avg =  13.7909 | soft‑eval =  13.8051 | best =  14.2158 | no_improve = 102 | time = 8s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  220 | train‑avg =  13.9915 | soft‑eval =  13.5657 | best =  14.2158 | no_improve = 112 | time = 8s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  230 | train‑avg =  13.7330 | soft‑eval =  13.9426 | best =  14.2158 | no_improve = 122 | time = 8s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  240 | train‑avg =  13.8039 | soft‑eval =  14.2197 | best =  14.2158 | no_improve = 132 | time = 9s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  250 | train‑avg =  13.9209 | soft‑eval =  13.8133 | best =  14.2716 | no_improve =  8 | time = 9s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  260 | train‑avg =  13.7423 | soft‑eval =  13.6180 | best =  14.2716 | no_improve = 18 | time = 10s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  270 | train‑avg =  14.0427 | soft‑eval =  13.8478 | best =  14.2716 | no_improve = 28 | time = 10s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  280 | train‑avg =  13.7577 | soft‑eval =  13.7496 | best =  14.2716 | no_improve = 38 | time = 10s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  290 | train‑avg =  13.5806 | soft‑eval =  13.6146 | best =  14.2716 | no_improve = 48 | time = 11s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  300 | train‑avg =  13.9609 | soft‑eval =  13.9644 | best =  14.2716 | no_improve = 58 | time = 11s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  310 | train‑avg =  13.6746 | soft‑eval =  13.7215 | best =  14.2716 | no_improve = 68 | time = 11s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  320 | train‑avg =  13.8340 | soft‑eval =  13.5958 | best =  14.2716 | no_improve = 78 | time = 12s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  330 | train‑avg =  13.9314 | soft‑eval =  13.9038 | best =  14.2716 | no_improve = 88 | time = 12s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  340 | train‑avg =  13.7298 | soft‑eval =  13.8944 | best =  14.2716 | no_improve = 98 | time = 13s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  350 | train‑avg =  13.7312 | soft‑eval =  13.5923 | best =  14.2716 | no_improve = 108 | time = 13s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  360 | train‑avg =  13.8951 | soft‑eval =  13.7762 | best =  14.2716 | no_improve = 118 | time = 13s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  370 | train‑avg =  13.7497 | soft‑eval =  13.9579 | best =  14.2716 | no_improve = 128 | time = 14s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  380 | train‑avg =  13.9698 | soft‑eval =  13.8163 | best =  14.2716 | no_improve = 138 | time = 14s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  390 | train‑avg =  13.6383 | soft‑eval =  14.0332 | best =  14.2716 | no_improve = 148 | time = 14s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  400 | train‑avg =  13.8328 | soft‑eval =  13.7789 | best =  14.2716 | no_improve = 158 | time = 15s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 3.50e-03
# Epoch  410 | train‑avg =  13.7633 | soft‑eval =  14.0355 | best =  14.2716 | no_improve = 168 | time = 15s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 3.50e-03
# Epoch  420 | train‑avg =  13.8974 | soft‑eval =  13.9204 | best =  14.2716 | no_improve = 178 | time = 16s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 3.50e-03
# Epoch  430 | train‑avg =  13.9976 | soft‑eval =  13.9489 | best =  14.2716 | no_improve = 188 | time = 16s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 3.50e-03
# Epoch  440 | train‑avg =  13.5957 | soft‑eval =  14.0021 | best =  14.2716 | no_improve = 198 | time = 16s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 3.50e-03
# Early stopping triggered after 442 epochs (16s)
# Best score: 14.271601
# No improvement for 200 epochs
#
# Training completed after 441 epochs
# Total training time: 16s
# Average time per epoch: 0.0s
# Best evaluation score: 14.271601
# Final score: 13.525706
#
# Evaluating final policy...
# Sharp policy price ≈ 13.8868  CI: [13.8737,13.8999] (95% CI)
# Setting up input normalization...
# Starting training with early stopping (patience=200, min_epochs=50)
# Will stop when improvement < 1.00e-02 absolute or < 1.00e-03 relative
# Epoch   10 | train‑avg =  13.7034 | soft‑eval =  13.8528 | best =  13.7383 | no_improve =  3 | time = 0s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch   20 | train‑avg =  13.6711 | soft‑eval =  13.8507 | best =  14.0235 | no_improve =  1 | time = 0s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch   30 | train‑avg =  13.9785 | soft‑eval =  13.7878 | best =  14.0471 | no_improve =  2 | time = 1s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch   40 | train‑avg =  13.6811 | soft‑eval =  13.8657 | best =  14.0471 | no_improve = 12 | time = 1s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch   50 | train‑avg =  13.8803 | soft‑eval =  13.6643 | best =  14.2140 | no_improve =  7 | time = 2s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch   60 | train‑avg =  13.9264 | soft‑eval =  13.9637 | best =  14.2140 | no_improve = 17 | time = 2s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch   70 | train‑avg =  13.7635 | soft‑eval =  14.0105 | best =  14.2140 | no_improve = 27 | time = 2s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch   80 | train‑avg =  13.7964 | soft‑eval =  13.7583 | best =  14.2140 | no_improve = 37 | time = 3s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch   90 | train‑avg =  13.8456 | soft‑eval =  14.1189 | best =  14.2140 | no_improve = 47 | time = 3s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  100 | train‑avg =  14.0783 | soft‑eval =  13.9862 | best =  14.2140 | no_improve = 57 | time = 4s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  110 | train‑avg =  13.8261 | soft‑eval =  13.8410 | best =  14.2140 | no_improve = 67 | time = 4s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  120 | train‑avg =  14.1146 | soft‑eval =  13.7672 | best =  14.2140 | no_improve = 77 | time = 4s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  130 | train‑avg =  13.8248 | soft‑eval =  13.7145 | best =  14.2140 | no_improve = 87 | time = 5s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  140 | train‑avg =  13.8613 | soft‑eval =  13.7243 | best =  14.2140 | no_improve = 97 | time = 5s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  150 | train‑avg =  13.8641 | soft‑eval =  13.7332 | best =  14.2140 | no_improve = 107 | time = 6s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  160 | train‑avg =  14.0646 | soft‑eval =  13.7223 | best =  14.2140 | no_improve = 117 | time = 6s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  170 | train‑avg =  13.9958 | soft‑eval =  13.6341 | best =  14.2140 | no_improve = 127 | time = 7s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  180 | train‑avg =  13.8887 | soft‑eval =  13.9110 | best =  14.2140 | no_improve = 137 | time = 7s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  190 | train‑avg =  13.9507 | soft‑eval =  13.6444 | best =  14.2140 | no_improve = 147 | time = 7s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  200 | train‑avg =  14.0142 | soft‑eval =  13.6687 | best =  14.2140 | no_improve = 157 | time = 8s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  210 | train‑avg =  13.8759 | soft‑eval =  13.7800 | best =  14.2140 | no_improve = 167 | time = 8s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  220 | train‑avg =  13.9450 | soft‑eval =  13.8073 | best =  14.2140 | no_improve = 177 | time = 9s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  230 | train‑avg =  13.8313 | soft‑eval =  14.2122 | best =  14.2140 | no_improve = 187 | time = 9s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  240 | train‑avg =  13.6707 | soft‑eval =  13.7634 | best =  14.2140 | no_improve = 197 | time = 10s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Early stopping triggered after 243 epochs (10s)
# Best score: 14.214007
# No improvement for 200 epochs
#
# Training completed after 242 epochs
# Total training time: 10s
# Average time per epoch: 0.0s
# Best evaluation score: 14.214007
# Final score: 13.972798
#
# Evaluating final policy...
# Sharp policy price ≈ 13.8896  CI: [13.8764,13.9028] (95% CI)
# Setting up input normalization...
# Starting training with early stopping (patience=200, min_epochs=50)
# Will stop when improvement < 1.00e-02 absolute or < 1.00e-03 relative
# Epoch   10 | train‑avg =  13.8102 | soft‑eval =  13.7635 | best =  13.7732 | no_improve =  0 | time = 0s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch   20 | train‑avg =  13.7157 | soft‑eval =  14.0358 | best =  13.9277 | no_improve =  6 | time = 0s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch   30 | train‑avg =  13.8559 | soft‑eval =  13.7604 | best =  14.0358 | no_improve =  9 | time = 1s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch   40 | train‑avg =  13.8415 | soft‑eval =  13.8978 | best =  14.0358 | no_improve = 19 | time = 1s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch   50 | train‑avg =  13.8077 | soft‑eval =  13.8967 | best =  14.0583 | no_improve =  7 | time = 2s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch   60 | train‑avg =  13.6936 | soft‑eval =  14.0679 | best =  14.0583 | no_improve = 17 | time = 2s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch   70 | train‑avg =  13.9514 | soft‑eval =  13.7563 | best =  14.0583 | no_improve = 27 | time = 2s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch   80 | train‑avg =  13.7703 | soft‑eval =  13.8304 | best =  14.0583 | no_improve = 37 | time = 3s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch   90 | train‑avg =  13.7690 | soft‑eval =  13.8315 | best =  14.0583 | no_improve = 47 | time = 3s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  100 | train‑avg =  14.0214 | soft‑eval =  13.7599 | best =  14.0583 | no_improve = 57 | time = 3s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  110 | train‑avg =  13.7223 | soft‑eval =  13.9289 | best =  14.1284 | no_improve =  7 | time = 4s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  120 | train‑avg =  13.9969 | soft‑eval =  13.7300 | best =  14.1284 | no_improve = 17 | time = 4s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  130 | train‑avg =  14.0001 | soft‑eval =  13.7255 | best =  14.1284 | no_improve = 27 | time = 5s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  140 | train‑avg =  13.9776 | soft‑eval =  13.8726 | best =  14.1284 | no_improve = 37 | time = 5s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  150 | train‑avg =  13.9078 | soft‑eval =  13.9827 | best =  14.1284 | no_improve = 47 | time = 6s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  160 | train‑avg =  13.8282 | soft‑eval =  13.7196 | best =  14.1284 | no_improve = 57 | time = 6s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  170 | train‑avg =  13.9774 | soft‑eval =  13.6997 | best =  14.1749 | no_improve =  1 | time = 6s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  180 | train‑avg =  13.7144 | soft‑eval =  13.9118 | best =  14.1749 | no_improve = 11 | time = 7s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  190 | train‑avg =  13.7801 | soft‑eval =  13.8936 | best =  14.1749 | no_improve = 21 | time = 7s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  200 | train‑avg =  13.8381 | soft‑eval =  13.8999 | best =  14.4009 | no_improve =  2 | time = 7s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  210 | train‑avg =  13.6773 | soft‑eval =  14.0372 | best =  14.4009 | no_improve = 12 | time = 8s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  220 | train‑avg =  13.8258 | soft‑eval =  13.6929 | best =  14.4009 | no_improve = 22 | time = 8s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 3.50e-03
# Epoch  230 | train‑avg =  13.6512 | soft‑eval =  13.8100 | best =  14.4009 | no_improve = 32 | time = 9s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 3.50e-03
# Epoch  240 | train‑avg =  13.7641 | soft‑eval =  13.7762 | best =  14.4009 | no_improve = 42 | time = 9s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 3.50e-03
# Epoch  250 | train‑avg =  13.6634 | soft‑eval =  13.8006 | best =  14.4009 | no_improve = 52 | time = 9s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 3.50e-03
# Epoch  260 | train‑avg =  13.4275 | soft‑eval =  13.9075 | best =  14.4009 | no_improve = 62 | time = 10s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 3.50e-03
# Epoch  270 | train‑avg =  13.9070 | soft‑eval =  13.6376 | best =  14.4009 | no_improve = 72 | time = 10s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 3.50e-03
# Epoch  280 | train‑avg =  13.8430 | soft‑eval =  13.5793 | best =  14.4009 | no_improve = 82 | time = 11s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 3.50e-03
# Epoch  290 | train‑avg =  14.0149 | soft‑eval =  13.8673 | best =  14.4009 | no_improve = 92 | time = 11s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 3.50e-03
# Epoch  300 | train‑avg =  14.0032 | soft‑eval =  13.7348 | best =  14.4009 | no_improve = 102 | time = 11s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 3.50e-03
# Epoch  310 | train‑avg =  13.7054 | soft‑eval =  13.7915 | best =  14.4009 | no_improve = 112 | time = 12s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 3.50e-03
# Epoch  320 | train‑avg =  13.6242 | soft‑eval =  13.5648 | best =  14.4009 | no_improve = 122 | time = 12s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 3.50e-03
# Epoch  330 | train‑avg =  13.9114 | soft‑eval =  13.8852 | best =  14.4009 | no_improve = 132 | time = 13s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 3.50e-03
# Epoch  340 | train‑avg =  13.6601 | soft‑eval =  13.7218 | best =  14.4009 | no_improve = 142 | time = 13s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 3.50e-03
# Epoch  350 | train‑avg =  13.7259 | soft‑eval =  13.9011 | best =  14.4009 | no_improve = 152 | time = 13s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 3.50e-03
# Epoch  360 | train‑avg =  13.8005 | soft‑eval =  13.6535 | best =  14.4009 | no_improve = 162 | time = 14s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 3.50e-03
# Epoch  370 | train‑avg =  13.8708 | soft‑eval =  13.9133 | best =  14.4009 | no_improve = 172 | time = 14s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 3.50e-03
# Epoch  380 | train‑avg =  14.0785 | soft‑eval =  13.9114 | best =  14.4009 | no_improve = 182 | time = 15s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 1.75e-03
# Epoch  390 | train‑avg =  13.8570 | soft‑eval =  13.8185 | best =  14.4009 | no_improve = 192 | time = 15s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 1.75e-03
# Early stopping triggered after 398 epochs (15s)
# Best score: 14.400857
# No improvement for 200 epochs
#
# Training completed after 397 epochs
# Total training time: 15s
# Average time per epoch: 0.0s
# Best evaluation score: 14.400857
# Final score: 13.920013
#
# Evaluating final policy...
# Sharp policy price ≈ 13.8900  CI: [13.8768,13.9032] (95% CI)
# Setting up input normalization...
# Starting training with early stopping (patience=200, min_epochs=50)
# Will stop when improvement < 1.00e-02 absolute or < 1.00e-03 relative
# Epoch   10 | train‑avg =  13.8695 | soft‑eval =  13.6198 | best =  14.0094 | no_improve =  0 | time = 0s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch   20 | train‑avg =  13.6704 | soft‑eval =  13.6597 | best =  14.0094 | no_improve = 10 | time = 0s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch   30 | train‑avg =  13.8661 | soft‑eval =  13.8438 | best =  14.1179 | no_improve =  3 | time = 1s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch   40 | train‑avg =  13.7071 | soft‑eval =  14.1386 | best =  14.1179 | no_improve = 13 | time = 1s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch   50 | train‑avg =  13.8355 | soft‑eval =  14.1558 | best =  14.1386 | no_improve =  9 | time = 1s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch   60 | train‑avg =  14.0187 | soft‑eval =  13.6510 | best =  14.3910 | no_improve =  5 | time = 2s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch   70 | train‑avg =  13.8351 | soft‑eval =  13.7595 | best =  14.3910 | no_improve = 15 | time = 2s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch   80 | train‑avg =  13.7560 | soft‑eval =  13.8035 | best =  14.3910 | no_improve = 25 | time = 3s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch   90 | train‑avg =  13.9418 | soft‑eval =  14.0032 | best =  14.3910 | no_improve = 35 | time = 3s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  100 | train‑avg =  13.6581 | soft‑eval =  14.1539 | best =  14.3910 | no_improve = 45 | time = 4s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  110 | train‑avg =  13.9780 | soft‑eval =  13.8397 | best =  14.3910 | no_improve = 55 | time = 4s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  120 | train‑avg =  13.6409 | soft‑eval =  13.9333 | best =  14.3910 | no_improve = 65 | time = 4s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  130 | train‑avg =  14.0583 | soft‑eval =  13.8374 | best =  14.3910 | no_improve = 75 | time = 5s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  140 | train‑avg =  13.9223 | soft‑eval =  13.9513 | best =  14.3910 | no_improve = 85 | time = 5s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  150 | train‑avg =  13.7869 | soft‑eval =  13.7599 | best =  14.3910 | no_improve = 95 | time = 5s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  160 | train‑avg =  13.7351 | soft‑eval =  13.7295 | best =  14.3910 | no_improve = 105 | time = 6s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  170 | train‑avg =  13.8826 | soft‑eval =  13.8669 | best =  14.3910 | no_improve = 115 | time = 6s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  180 | train‑avg =  14.0371 | soft‑eval =  14.0240 | best =  14.3910 | no_improve = 125 | time = 7s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  190 | train‑avg =  13.8278 | soft‑eval =  13.9807 | best =  14.3910 | no_improve = 135 | time = 7s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  200 | train‑avg =  13.9441 | soft‑eval =  13.9406 | best =  14.3910 | no_improve = 145 | time = 7s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  210 | train‑avg =  13.7150 | soft‑eval =  13.9526 | best =  14.3910 | no_improve = 155 | time = 8s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 3.50e-03
# Epoch  220 | train‑avg =  13.9320 | soft‑eval =  13.8378 | best =  14.3910 | no_improve = 165 | time = 8s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 3.50e-03
# Epoch  230 | train‑avg =  13.8503 | soft‑eval =  13.7731 | best =  14.3910 | no_improve = 175 | time = 9s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 3.50e-03
# Epoch  240 | train‑avg =  13.8339 | soft‑eval =  14.0807 | best =  14.3910 | no_improve = 185 | time = 9s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 3.50e-03
# Epoch  250 | train‑avg =  13.8287 | soft‑eval =  14.2807 | best =  14.3910 | no_improve = 195 | time = 10s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 3.50e-03
# Early stopping triggered after 255 epochs (10s)
# Best score: 14.391017
# No improvement for 200 epochs
#
# Training completed after 254 epochs
# Total training time: 10s
# Average time per epoch: 0.0s
# Best evaluation score: 14.391017
# Final score: 13.927550
#
# Evaluating final policy...
# Sharp policy price ≈ 13.8845  CI: [13.8712,13.8977] (95% CI)
# Setting up input normalization...
# Starting training with early stopping (patience=200, min_epochs=50)
# Will stop when improvement < 1.00e-02 absolute or < 1.00e-03 relative
# Epoch   10 | train‑avg =  13.8186 | soft‑eval =  13.6493 | best =  13.8673 | no_improve =  1 | time = 0s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch   20 | train‑avg =  14.0512 | soft‑eval =  13.7593 | best =  14.1275 | no_improve =  3 | time = 0s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch   30 | train‑avg =  13.8206 | soft‑eval =  13.7741 | best =  14.1275 | no_improve = 13 | time = 1s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch   40 | train‑avg =  13.6859 | soft‑eval =  13.7010 | best =  14.1275 | no_improve = 23 | time = 1s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch   50 | train‑avg =  13.7862 | soft‑eval =  13.8420 | best =  14.1275 | no_improve = 33 | time = 2s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch   60 | train‑avg =  13.6508 | soft‑eval =  13.8494 | best =  14.2560 | no_improve =  1 | time = 2s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch   70 | train‑avg =  13.7492 | soft‑eval =  14.1514 | best =  14.2560 | no_improve = 11 | time = 2s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch   80 | train‑avg =  13.6683 | soft‑eval =  13.7805 | best =  14.2560 | no_improve = 21 | time = 3s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch   90 | train‑avg =  13.9616 | soft‑eval =  13.4637 | best =  14.2560 | no_improve = 31 | time = 3s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  100 | train‑avg =  13.8660 | soft‑eval =  13.8036 | best =  14.2560 | no_improve = 41 | time = 4s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  110 | train‑avg =  13.9407 | soft‑eval =  13.9034 | best =  14.2560 | no_improve = 51 | time = 4s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  120 | train‑avg =  13.9229 | soft‑eval =  14.0381 | best =  14.2560 | no_improve = 61 | time = 5s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  130 | train‑avg =  13.8190 | soft‑eval =  13.7018 | best =  14.2560 | no_improve = 71 | time = 5s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  140 | train‑avg =  13.9356 | soft‑eval =  13.7046 | best =  14.2560 | no_improve = 81 | time = 5s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  150 | train‑avg =  13.5999 | soft‑eval =  13.8358 | best =  14.2560 | no_improve = 91 | time = 6s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  160 | train‑avg =  13.8636 | soft‑eval =  13.6877 | best =  14.2560 | no_improve = 101 | time = 6s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  170 | train‑avg =  13.6207 | soft‑eval =  14.0177 | best =  14.2560 | no_improve = 111 | time = 6s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  180 | train‑avg =  13.7336 | soft‑eval =  13.7860 | best =  14.2560 | no_improve = 121 | time = 7s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  190 | train‑avg =  13.9868 | soft‑eval =  13.9096 | best =  14.2560 | no_improve = 131 | time = 7s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  200 | train‑avg =  14.1066 | soft‑eval =  13.7498 | best =  14.2560 | no_improve = 141 | time = 8s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  210 | train‑avg =  13.9106 | soft‑eval =  13.9882 | best =  14.2560 | no_improve = 151 | time = 8s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  220 | train‑avg =  13.6798 | soft‑eval =  13.9670 | best =  14.2560 | no_improve = 161 | time = 8s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  230 | train‑avg =  13.9651 | soft‑eval =  13.7940 | best =  14.4235 | no_improve =  4 | time = 9s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 3.50e-03
# Epoch  240 | train‑avg =  13.8935 | soft‑eval =  13.7630 | best =  14.4235 | no_improve = 14 | time = 9s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 3.50e-03
# Epoch  250 | train‑avg =  13.8947 | soft‑eval =  13.7163 | best =  14.4235 | no_improve = 24 | time = 10s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 3.50e-03
# Epoch  260 | train‑avg =  13.9697 | soft‑eval =  13.9704 | best =  14.4235 | no_improve = 34 | time = 10s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 3.50e-03
# Epoch  270 | train‑avg =  13.9460 | soft‑eval =  13.5915 | best =  14.4235 | no_improve = 44 | time = 11s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 3.50e-03
# Epoch  280 | train‑avg =  13.9906 | soft‑eval =  14.0133 | best =  14.4235 | no_improve = 54 | time = 11s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 3.50e-03
# Epoch  290 | train‑avg =  13.8145 | soft‑eval =  13.8715 | best =  14.4235 | no_improve = 64 | time = 11s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 3.50e-03
# Epoch  300 | train‑avg =  13.5720 | soft‑eval =  13.7972 | best =  14.4235 | no_improve = 74 | time = 12s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 3.50e-03
# Epoch  310 | train‑avg =  13.7443 | soft‑eval =  13.9796 | best =  14.4235 | no_improve = 84 | time = 12s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 3.50e-03
# Epoch  320 | train‑avg =  13.9506 | soft‑eval =  13.9799 | best =  14.4235 | no_improve = 94 | time = 13s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 3.50e-03
# Epoch  330 | train‑avg =  13.8564 | soft‑eval =  13.8121 | best =  14.4235 | no_improve = 104 | time = 13s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 3.50e-03
# Epoch  340 | train‑avg =  13.7902 | soft‑eval =  13.6403 | best =  14.4235 | no_improve = 114 | time = 14s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 3.50e-03
# Epoch  350 | train‑avg =  13.9626 | soft‑eval =  14.0731 | best =  14.4235 | no_improve = 124 | time = 14s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 3.50e-03
# Epoch  360 | train‑avg =  13.7353 | soft‑eval =  13.5792 | best =  14.4235 | no_improve = 134 | time = 14s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 3.50e-03
# Epoch  370 | train‑avg =  13.9610 | soft‑eval =  13.7956 | best =  14.4235 | no_improve = 144 | time = 15s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 3.50e-03
# Epoch  380 | train‑avg =  13.8412 | soft‑eval =  13.6687 | best =  14.4235 | no_improve = 154 | time = 15s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 3.50e-03
# Epoch  390 | train‑avg =  13.7005 | soft‑eval =  13.8273 | best =  14.4235 | no_improve = 164 | time = 16s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 1.75e-03
# Epoch  400 | train‑avg =  13.8612 | soft‑eval =  13.8497 | best =  14.4235 | no_improve = 174 | time = 16s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 1.75e-03
# Epoch  410 | train‑avg =  13.9887 | soft‑eval =  13.6979 | best =  14.4235 | no_improve = 184 | time = 16s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 1.75e-03
# Epoch  420 | train‑avg =  13.8604 | soft‑eval =  14.0105 | best =  14.4235 | no_improve = 194 | time = 17s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 1.75e-03
# Early stopping triggered after 426 epochs (17s)
# Best score: 14.423521
# No improvement for 200 epochs
#
# Training completed after 425 epochs
# Total training time: 17s
# Average time per epoch: 0.0s
# Best evaluation score: 14.423521
# Final score: 14.100674
#
# Evaluating final policy...
# Sharp policy price ≈ 13.8919  CI: [13.8787,13.9051] (95% CI)

# %%
print(f"Price = {np.mean(prices):.3f} ({np.std(prices):.3f})")
print(f"Max Price = {np.max(prices):.3f}")
print(f"Times = {times}")
# Out:
# Price = 13.887 (0.004)
# Max Price = 13.892
# Times = ['10s', '31s', '11s', '16s', '10s', '15s', '10s', '17s']

# %%
times = ['10s', '31s', '11s', '16s', '10s', '15s', '10s', '17s']
print(f"Average training time = {average_time_in_seconds(times)}")
# Out:
# Average training time = 15.0

# %% [markdown]
# # d = 5

# %%
d = 5
seed = 42

prices = []
times = []
n_trials = 8

for trial in range(n_trials):
    net, train_hist, eval_hist, training_time = train_net(
    soft_sigma=2.0,
    N_train=10_000,
    batch=500,
    lr=0.007,
    seed=seed + trial,
    eval_every=10,
    width=64,
    depth=2,
    dropout=0.1,
    curriculum=False,
    patience=200,            
    min_delta=1e-2,      
    relative_threshold=1e-3,
    min_epochs=50,         
    max_epochs=2000     
    )
    times.append(training_time)

    print("\nEvaluating final policy...")
    sharp_mean, sharp_se = evaluate_sharp_policy(net, N_eval=5_000_000)
    prices.append(sharp_mean)
    print(f"Sharp policy price ≈ {sharp_mean:.4f}  CI: [{sharp_mean - 1.96*sharp_se:.4f},{sharp_mean + 1.96*sharp_se:.4f}] (95% CI)")
# Out:
# Setting up input normalization...
# Starting training with early stopping (patience=200, min_epochs=50)
# Will stop when improvement < 1.00e-02 absolute or < 1.00e-03 relative
# Epoch   10 | train‑avg =  25.3125 | soft‑eval =  25.0067 | best =  24.6955 | no_improve =  1 | time = 0s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch   20 | train‑avg =  25.6957 | soft‑eval =  25.8577 | best =  25.9975 | no_improve =  4 | time = 0s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch   30 | train‑avg =  25.7148 | soft‑eval =  25.4968 | best =  26.0327 | no_improve =  7 | time = 1s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch   40 | train‑avg =  25.5437 | soft‑eval =  26.2114 | best =  26.2684 | no_improve =  4 | time = 1s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch   50 | train‑avg =  25.8283 | soft‑eval =  25.8653 | best =  26.2684 | no_improve = 14 | time = 2s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch   60 | train‑avg =  25.9160 | soft‑eval =  26.0229 | best =  26.2684 | no_improve = 24 | time = 2s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch   70 | train‑avg =  26.1599 | soft‑eval =  26.0986 | best =  26.2684 | no_improve = 34 | time = 3s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch   80 | train‑avg =  26.1447 | soft‑eval =  25.8585 | best =  26.2684 | no_improve = 44 | time = 3s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch   90 | train‑avg =  26.2309 | soft‑eval =  25.9243 | best =  26.2684 | no_improve = 54 | time = 4s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  100 | train‑avg =  25.9286 | soft‑eval =  25.9019 | best =  26.2684 | no_improve = 64 | time = 4s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  110 | train‑avg =  25.6366 | soft‑eval =  26.1356 | best =  26.2684 | no_improve = 74 | time = 5s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  120 | train‑avg =  25.8751 | soft‑eval =  25.9587 | best =  26.2684 | no_improve = 84 | time = 5s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  130 | train‑avg =  26.4034 | soft‑eval =  25.6791 | best =  26.2684 | no_improve = 94 | time = 6s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  140 | train‑avg =  25.9331 | soft‑eval =  25.8361 | best =  26.3186 | no_improve =  1 | time = 6s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  150 | train‑avg =  26.0622 | soft‑eval =  25.7182 | best =  26.3898 | no_improve =  7 | time = 7s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  160 | train‑avg =  25.9407 | soft‑eval =  25.9162 | best =  26.3898 | no_improve = 17 | time = 7s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  170 | train‑avg =  25.9376 | soft‑eval =  26.2446 | best =  26.3898 | no_improve = 27 | time = 8s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  180 | train‑avg =  25.7875 | soft‑eval =  26.0914 | best =  26.3898 | no_improve = 37 | time = 8s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  190 | train‑avg =  26.1219 | soft‑eval =  25.9658 | best =  26.3898 | no_improve = 47 | time = 9s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  200 | train‑avg =  26.2936 | soft‑eval =  26.1697 | best =  26.3898 | no_improve = 57 | time = 9s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  210 | train‑avg =  26.0661 | soft‑eval =  25.9581 | best =  26.3898 | no_improve = 67 | time = 10s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  220 | train‑avg =  25.8572 | soft‑eval =  25.8994 | best =  26.3898 | no_improve = 77 | time = 10s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  230 | train‑avg =  26.0503 | soft‑eval =  26.2089 | best =  26.4554 | no_improve =  8 | time = 10s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  240 | train‑avg =  25.8568 | soft‑eval =  26.0356 | best =  26.4554 | no_improve = 18 | time = 11s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  250 | train‑avg =  26.0282 | soft‑eval =  26.1120 | best =  26.5036 | no_improve =  1 | time = 11s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  260 | train‑avg =  26.0944 | soft‑eval =  26.0107 | best =  26.5036 | no_improve = 11 | time = 12s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  270 | train‑avg =  25.5304 | soft‑eval =  26.2789 | best =  26.5036 | no_improve = 21 | time = 12s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  280 | train‑avg =  26.1883 | soft‑eval =  25.9102 | best =  26.5036 | no_improve = 31 | time = 13s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  290 | train‑avg =  25.7339 | soft‑eval =  25.9794 | best =  26.5036 | no_improve = 41 | time = 13s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  300 | train‑avg =  26.3630 | soft‑eval =  26.1878 | best =  26.5036 | no_improve = 51 | time = 14s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  310 | train‑avg =  26.0279 | soft‑eval =  25.9629 | best =  26.5036 | no_improve = 61 | time = 14s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  320 | train‑avg =  26.0794 | soft‑eval =  26.1949 | best =  26.5036 | no_improve = 71 | time = 15s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  330 | train‑avg =  26.0929 | soft‑eval =  25.8991 | best =  26.5036 | no_improve = 81 | time = 15s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  340 | train‑avg =  26.1532 | soft‑eval =  25.9551 | best =  26.5036 | no_improve = 91 | time = 16s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  350 | train‑avg =  26.1451 | soft‑eval =  25.9745 | best =  26.5036 | no_improve = 101 | time = 16s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  360 | train‑avg =  26.0456 | soft‑eval =  26.0147 | best =  26.5036 | no_improve = 111 | time = 17s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  370 | train‑avg =  25.7891 | soft‑eval =  26.0710 | best =  26.5036 | no_improve = 121 | time = 17s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  380 | train‑avg =  25.7692 | soft‑eval =  25.9458 | best =  26.5036 | no_improve = 131 | time = 18s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  390 | train‑avg =  26.0049 | soft‑eval =  25.7289 | best =  26.5036 | no_improve = 141 | time = 18s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  400 | train‑avg =  25.8856 | soft‑eval =  25.9635 | best =  26.5036 | no_improve = 151 | time = 19s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  410 | train‑avg =  26.1250 | soft‑eval =  26.2471 | best =  26.5036 | no_improve = 161 | time = 19s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  420 | train‑avg =  26.0813 | soft‑eval =  25.9092 | best =  26.5036 | no_improve = 171 | time = 19s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  430 | train‑avg =  25.9609 | soft‑eval =  26.3323 | best =  26.5036 | no_improve = 181 | time = 20s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  440 | train‑avg =  26.0013 | soft‑eval =  25.9824 | best =  26.5036 | no_improve = 191 | time = 20s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Early stopping triggered after 449 epochs (21s)
# Best score: 26.503551
# No improvement for 200 epochs
#
# Training completed after 448 epochs
# Total training time: 21s
# Average time per epoch: 0.0s
# Best evaluation score: 26.503551
# Final score: 26.108745
#
# Evaluating final policy...
# Sharp policy price ≈ 26.0922  CI: [26.0750,26.1093] (95% CI)
# Setting up input normalization...
# Starting training with early stopping (patience=200, min_epochs=50)
# Will stop when improvement < 1.00e-02 absolute or < 1.00e-03 relative
# Epoch   10 | train‑avg =  25.0622 | soft‑eval =  25.5781 | best =  25.0181 | no_improve =  1 | time = 0s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch   20 | train‑avg =  25.7041 | soft‑eval =  25.9145 | best =  25.9344 | no_improve =  6 | time = 0s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch   30 | train‑avg =  25.5679 | soft‑eval =  25.3871 | best =  26.0170 | no_improve =  8 | time = 1s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch   40 | train‑avg =  25.8275 | soft‑eval =  26.1576 | best =  26.0170 | no_improve = 18 | time = 1s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch   50 | train‑avg =  26.5819 | soft‑eval =  25.9383 | best =  26.1576 | no_improve =  9 | time = 2s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch   60 | train‑avg =  25.8789 | soft‑eval =  25.7729 | best =  26.1837 | no_improve =  6 | time = 2s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch   70 | train‑avg =  25.8296 | soft‑eval =  25.9771 | best =  26.1837 | no_improve = 16 | time = 3s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch   80 | train‑avg =  25.7336 | soft‑eval =  26.0016 | best =  26.1837 | no_improve = 26 | time = 3s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch   90 | train‑avg =  26.1225 | soft‑eval =  25.5916 | best =  26.3701 | no_improve =  3 | time = 4s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  100 | train‑avg =  26.0949 | soft‑eval =  25.9121 | best =  26.3701 | no_improve = 13 | time = 4s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  110 | train‑avg =  26.1664 | soft‑eval =  26.1022 | best =  26.3701 | no_improve = 23 | time = 5s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  120 | train‑avg =  25.9331 | soft‑eval =  26.1257 | best =  26.3701 | no_improve = 33 | time = 5s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  130 | train‑avg =  25.9424 | soft‑eval =  26.0793 | best =  26.3701 | no_improve = 43 | time = 6s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  140 | train‑avg =  25.7684 | soft‑eval =  25.9555 | best =  26.3701 | no_improve = 53 | time = 6s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  150 | train‑avg =  25.9636 | soft‑eval =  26.2274 | best =  26.3701 | no_improve = 63 | time = 7s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  160 | train‑avg =  26.2494 | soft‑eval =  25.5053 | best =  26.3701 | no_improve = 73 | time = 7s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  170 | train‑avg =  26.0253 | soft‑eval =  26.0805 | best =  26.3701 | no_improve = 83 | time = 8s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  180 | train‑avg =  25.9661 | soft‑eval =  25.9750 | best =  26.3701 | no_improve = 93 | time = 8s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  190 | train‑avg =  26.0837 | soft‑eval =  26.0394 | best =  26.3701 | no_improve = 103 | time = 9s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  200 | train‑avg =  26.4886 | soft‑eval =  26.3208 | best =  26.3701 | no_improve = 113 | time = 9s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  210 | train‑avg =  26.0910 | soft‑eval =  26.0418 | best =  26.3701 | no_improve = 123 | time = 9s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  220 | train‑avg =  25.5726 | soft‑eval =  26.2638 | best =  26.3701 | no_improve = 133 | time = 10s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  230 | train‑avg =  25.9841 | soft‑eval =  26.0913 | best =  26.3701 | no_improve = 143 | time = 10s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  240 | train‑avg =  26.0806 | soft‑eval =  26.0820 | best =  26.3701 | no_improve = 153 | time = 11s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  250 | train‑avg =  25.8653 | soft‑eval =  25.7989 | best =  26.3701 | no_improve = 163 | time = 11s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  260 | train‑avg =  25.9539 | soft‑eval =  25.9621 | best =  26.3986 | no_improve =  4 | time = 12s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  270 | train‑avg =  25.9710 | soft‑eval =  25.8767 | best =  26.3986 | no_improve = 14 | time = 12s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  280 | train‑avg =  25.9526 | soft‑eval =  26.1186 | best =  26.3986 | no_improve = 24 | time = 12s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  290 | train‑avg =  25.8951 | soft‑eval =  25.9462 | best =  26.3986 | no_improve = 34 | time = 13s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  300 | train‑avg =  25.8119 | soft‑eval =  25.8461 | best =  26.3986 | no_improve = 44 | time = 13s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  310 | train‑avg =  25.9205 | soft‑eval =  25.7248 | best =  26.3986 | no_improve = 54 | time = 14s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  320 | train‑avg =  26.1256 | soft‑eval =  26.1515 | best =  26.3986 | no_improve = 64 | time = 14s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  330 | train‑avg =  26.1669 | soft‑eval =  26.3067 | best =  26.3986 | no_improve = 74 | time = 15s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  340 | train‑avg =  25.9061 | soft‑eval =  25.9448 | best =  26.3986 | no_improve = 84 | time = 15s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  350 | train‑avg =  25.6248 | soft‑eval =  26.1809 | best =  26.3986 | no_improve = 94 | time = 16s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  360 | train‑avg =  25.7921 | soft‑eval =  25.7851 | best =  26.3986 | no_improve = 104 | time = 16s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 3.50e-03
# Epoch  370 | train‑avg =  25.8665 | soft‑eval =  26.2098 | best =  26.3986 | no_improve = 114 | time = 16s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 3.50e-03
# Epoch  380 | train‑avg =  26.3775 | soft‑eval =  26.0832 | best =  26.3986 | no_improve = 124 | time = 17s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 3.50e-03
# Epoch  390 | train‑avg =  25.8503 | soft‑eval =  26.3824 | best =  26.3986 | no_improve = 134 | time = 17s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 3.50e-03
# Epoch  400 | train‑avg =  25.6729 | soft‑eval =  25.9573 | best =  26.3986 | no_improve = 144 | time = 18s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 3.50e-03
# Epoch  410 | train‑avg =  26.0153 | soft‑eval =  26.3175 | best =  26.3986 | no_improve = 154 | time = 18s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 3.50e-03
# Epoch  420 | train‑avg =  26.1643 | soft‑eval =  26.0192 | best =  26.3986 | no_improve = 164 | time = 19s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 3.50e-03
# Epoch  430 | train‑avg =  26.1520 | soft‑eval =  26.1275 | best =  26.3986 | no_improve = 174 | time = 19s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 3.50e-03
# Epoch  440 | train‑avg =  26.1605 | soft‑eval =  26.0421 | best =  26.3986 | no_improve = 184 | time = 20s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 3.50e-03
# Epoch  450 | train‑avg =  25.8281 | soft‑eval =  25.9614 | best =  26.3986 | no_improve = 194 | time = 20s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 3.50e-03
# Early stopping triggered after 456 epochs (20s)
# Best score: 26.398585
# No improvement for 200 epochs
#
# Training completed after 455 epochs
# Total training time: 20s
# Average time per epoch: 0.0s
# Best evaluation score: 26.398585
# Final score: 25.942421
#
# Evaluating final policy...
# Sharp policy price ≈ 26.0985  CI: [26.0815,26.1155] (95% CI)
# Setting up input normalization...
# Starting training with early stopping (patience=200, min_epochs=50)
# Will stop when improvement < 1.00e-02 absolute or < 1.00e-03 relative
# Epoch   10 | train‑avg =  24.8562 | soft‑eval =  24.8371 | best =  25.1259 | no_improve =  0 | time = 0s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch   20 | train‑avg =  26.1039 | soft‑eval =  25.9870 | best =  26.0764 | no_improve =  3 | time = 0s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch   30 | train‑avg =  26.0008 | soft‑eval =  25.7198 | best =  26.2860 | no_improve =  4 | time = 1s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch   40 | train‑avg =  25.8325 | soft‑eval =  26.0596 | best =  26.2860 | no_improve = 14 | time = 1s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch   50 | train‑avg =  25.4601 | soft‑eval =  25.8642 | best =  26.2860 | no_improve = 24 | time = 2s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch   60 | train‑avg =  25.7774 | soft‑eval =  25.4767 | best =  26.4220 | no_improve =  3 | time = 2s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch   70 | train‑avg =  26.0589 | soft‑eval =  25.9029 | best =  26.4220 | no_improve = 13 | time = 3s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch   80 | train‑avg =  25.6521 | soft‑eval =  25.8853 | best =  26.4220 | no_improve = 23 | time = 3s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch   90 | train‑avg =  25.9472 | soft‑eval =  25.7533 | best =  26.4220 | no_improve = 33 | time = 3s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  100 | train‑avg =  25.7717 | soft‑eval =  25.8537 | best =  26.4220 | no_improve = 43 | time = 4s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  110 | train‑avg =  26.0170 | soft‑eval =  26.1241 | best =  26.4220 | no_improve = 53 | time = 4s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  120 | train‑avg =  26.0285 | soft‑eval =  25.8586 | best =  26.4220 | no_improve = 63 | time = 5s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  130 | train‑avg =  26.0944 | soft‑eval =  25.9994 | best =  26.4220 | no_improve = 73 | time = 5s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  140 | train‑avg =  26.1802 | soft‑eval =  25.9027 | best =  26.4220 | no_improve = 83 | time = 6s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  150 | train‑avg =  25.8266 | soft‑eval =  26.0266 | best =  26.4220 | no_improve = 93 | time = 6s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  160 | train‑avg =  25.7633 | soft‑eval =  26.0209 | best =  26.4220 | no_improve = 103 | time = 6s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  170 | train‑avg =  26.3712 | soft‑eval =  25.8400 | best =  26.4220 | no_improve = 113 | time = 7s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  180 | train‑avg =  25.8816 | soft‑eval =  25.6104 | best =  26.4220 | no_improve = 123 | time = 7s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  190 | train‑avg =  26.0942 | soft‑eval =  26.1212 | best =  26.4854 | no_improve =  8 | time = 8s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  200 | train‑avg =  26.3282 | soft‑eval =  26.0617 | best =  26.4854 | no_improve = 18 | time = 8s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  210 | train‑avg =  26.1606 | soft‑eval =  26.0542 | best =  26.4854 | no_improve = 28 | time = 9s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  220 | train‑avg =  25.7456 | soft‑eval =  25.6932 | best =  26.4854 | no_improve = 38 | time = 9s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  230 | train‑avg =  25.9020 | soft‑eval =  25.9690 | best =  26.4854 | no_improve = 48 | time = 10s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  240 | train‑avg =  26.0245 | soft‑eval =  25.9995 | best =  26.4854 | no_improve = 58 | time = 10s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  250 | train‑avg =  25.9797 | soft‑eval =  26.1813 | best =  26.4854 | no_improve = 68 | time = 10s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  260 | train‑avg =  25.9265 | soft‑eval =  25.9902 | best =  26.4854 | no_improve = 78 | time = 11s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  270 | train‑avg =  25.8699 | soft‑eval =  25.8669 | best =  26.4854 | no_improve = 88 | time = 11s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  280 | train‑avg =  25.7157 | soft‑eval =  25.7670 | best =  26.4854 | no_improve = 98 | time = 12s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  290 | train‑avg =  26.4046 | soft‑eval =  26.5814 | best =  26.4854 | no_improve = 108 | time = 12s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  300 | train‑avg =  25.8951 | soft‑eval =  25.9086 | best =  26.5814 | no_improve =  9 | time = 13s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  310 | train‑avg =  25.9418 | soft‑eval =  25.9672 | best =  26.5814 | no_improve = 19 | time = 13s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  320 | train‑avg =  25.9375 | soft‑eval =  26.0496 | best =  26.5814 | no_improve = 29 | time = 14s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  330 | train‑avg =  25.9314 | soft‑eval =  25.9213 | best =  26.5814 | no_improve = 39 | time = 14s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  340 | train‑avg =  26.0779 | soft‑eval =  25.9788 | best =  26.5814 | no_improve = 49 | time = 15s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  350 | train‑avg =  26.1429 | soft‑eval =  25.9666 | best =  26.5814 | no_improve = 59 | time = 15s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  360 | train‑avg =  25.8756 | soft‑eval =  26.2879 | best =  26.5814 | no_improve = 69 | time = 15s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  370 | train‑avg =  25.7480 | soft‑eval =  25.6944 | best =  26.5814 | no_improve = 79 | time = 16s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  380 | train‑avg =  25.8129 | soft‑eval =  26.1234 | best =  26.5814 | no_improve = 89 | time = 16s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  390 | train‑avg =  26.1356 | soft‑eval =  25.9785 | best =  26.5814 | no_improve = 99 | time = 17s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  400 | train‑avg =  26.0658 | soft‑eval =  26.3706 | best =  26.5814 | no_improve = 109 | time = 17s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  410 | train‑avg =  25.9987 | soft‑eval =  26.0445 | best =  26.5814 | no_improve = 119 | time = 18s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  420 | train‑avg =  25.8656 | soft‑eval =  25.9527 | best =  26.5814 | no_improve = 129 | time = 18s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  430 | train‑avg =  26.0198 | soft‑eval =  26.0759 | best =  26.5814 | no_improve = 139 | time = 18s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  440 | train‑avg =  26.1727 | soft‑eval =  25.8756 | best =  26.5814 | no_improve = 149 | time = 19s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  450 | train‑avg =  26.3039 | soft‑eval =  25.7223 | best =  26.5814 | no_improve = 159 | time = 19s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 3.50e-03
# Epoch  460 | train‑avg =  26.0159 | soft‑eval =  26.1016 | best =  26.5814 | no_improve = 169 | time = 20s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 3.50e-03
# Epoch  470 | train‑avg =  25.8212 | soft‑eval =  26.0205 | best =  26.5814 | no_improve = 179 | time = 20s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 3.50e-03
# Epoch  480 | train‑avg =  25.6189 | soft‑eval =  26.0310 | best =  26.5814 | no_improve = 189 | time = 21s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 3.50e-03
# Epoch  490 | train‑avg =  26.3279 | soft‑eval =  26.0961 | best =  26.5814 | no_improve = 199 | time = 21s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 3.50e-03
# Early stopping triggered after 491 epochs (21s)
# Best score: 26.581381
# No improvement for 200 epochs
#
# Training completed after 490 epochs
# Total training time: 21s
# Average time per epoch: 0.0s
# Best evaluation score: 26.581381
# Final score: 26.096088
#
# Evaluating final policy...
# Sharp policy price ≈ 26.1107  CI: [26.0937,26.1277] (95% CI)
# Setting up input normalization...
# Starting training with early stopping (patience=200, min_epochs=50)
# Will stop when improvement < 1.00e-02 absolute or < 1.00e-03 relative
# Epoch   10 | train‑avg =  24.9073 | soft‑eval =  25.0987 | best =  25.0583 | no_improve =  1 | time = 0s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch   20 | train‑avg =  25.5991 | soft‑eval =  26.0588 | best =  25.9672 | no_improve =  7 | time = 0s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch   30 | train‑avg =  25.8037 | soft‑eval =  25.8523 | best =  26.1254 | no_improve =  2 | time = 1s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch   40 | train‑avg =  25.9337 | soft‑eval =  25.8112 | best =  26.1254 | no_improve = 12 | time = 1s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch   50 | train‑avg =  26.0406 | soft‑eval =  26.0426 | best =  26.1460 | no_improve =  8 | time = 2s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch   60 | train‑avg =  25.5951 | soft‑eval =  25.9326 | best =  26.1724 | no_improve =  3 | time = 2s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch   70 | train‑avg =  25.7922 | soft‑eval =  25.8596 | best =  26.2677 | no_improve =  1 | time = 3s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch   80 | train‑avg =  26.0807 | soft‑eval =  25.8798 | best =  26.2957 | no_improve =  2 | time = 3s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch   90 | train‑avg =  25.8645 | soft‑eval =  25.8555 | best =  26.2957 | no_improve = 12 | time = 4s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  100 | train‑avg =  26.1562 | soft‑eval =  26.1184 | best =  26.2957 | no_improve = 22 | time = 4s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  110 | train‑avg =  26.2678 | soft‑eval =  25.9882 | best =  26.2957 | no_improve = 32 | time = 4s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  120 | train‑avg =  26.0369 | soft‑eval =  26.0968 | best =  26.2957 | no_improve = 42 | time = 5s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  130 | train‑avg =  26.1081 | soft‑eval =  26.1090 | best =  26.2957 | no_improve = 52 | time = 5s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  140 | train‑avg =  26.1645 | soft‑eval =  25.7560 | best =  26.2957 | no_improve = 62 | time = 6s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  150 | train‑avg =  25.9181 | soft‑eval =  26.2294 | best =  26.2957 | no_improve = 72 | time = 6s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  160 | train‑avg =  26.1411 | soft‑eval =  26.0033 | best =  26.2957 | no_improve = 82 | time = 7s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  170 | train‑avg =  25.5365 | soft‑eval =  26.0225 | best =  26.3782 | no_improve =  7 | time = 7s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  180 | train‑avg =  26.0079 | soft‑eval =  26.1311 | best =  26.3782 | no_improve = 17 | time = 8s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  190 | train‑avg =  25.8619 | soft‑eval =  25.6949 | best =  26.5921 | no_improve =  4 | time = 8s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  200 | train‑avg =  25.8908 | soft‑eval =  25.7411 | best =  26.5921 | no_improve = 14 | time = 8s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  210 | train‑avg =  26.4049 | soft‑eval =  26.0019 | best =  26.5921 | no_improve = 24 | time = 9s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  220 | train‑avg =  26.1505 | soft‑eval =  26.1144 | best =  26.5921 | no_improve = 34 | time = 9s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  230 | train‑avg =  25.8811 | soft‑eval =  25.9601 | best =  26.5921 | no_improve = 44 | time = 10s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  240 | train‑avg =  25.7942 | soft‑eval =  26.1598 | best =  26.5921 | no_improve = 54 | time = 10s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  250 | train‑avg =  26.0745 | soft‑eval =  26.1234 | best =  26.5921 | no_improve = 64 | time = 11s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  260 | train‑avg =  26.0830 | soft‑eval =  26.1830 | best =  26.5921 | no_improve = 74 | time = 11s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  270 | train‑avg =  26.2814 | soft‑eval =  26.1326 | best =  26.5921 | no_improve = 84 | time = 12s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  280 | train‑avg =  25.9839 | soft‑eval =  25.7306 | best =  26.5921 | no_improve = 94 | time = 12s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  290 | train‑avg =  26.2601 | soft‑eval =  25.6368 | best =  26.5921 | no_improve = 104 | time = 12s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  300 | train‑avg =  26.0248 | soft‑eval =  25.7972 | best =  26.5921 | no_improve = 114 | time = 13s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  310 | train‑avg =  26.2112 | soft‑eval =  26.2122 | best =  26.5921 | no_improve = 124 | time = 13s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 3.50e-03
# Epoch  320 | train‑avg =  25.9690 | soft‑eval =  25.8237 | best =  26.5921 | no_improve = 134 | time = 14s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 3.50e-03
# Epoch  330 | train‑avg =  25.8865 | soft‑eval =  26.3690 | best =  26.5921 | no_improve = 144 | time = 14s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 3.50e-03
# Epoch  340 | train‑avg =  25.8682 | soft‑eval =  25.9655 | best =  26.5921 | no_improve = 154 | time = 15s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 3.50e-03
# Epoch  350 | train‑avg =  26.3067 | soft‑eval =  25.8419 | best =  26.5921 | no_improve = 164 | time = 15s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 3.50e-03
# Epoch  360 | train‑avg =  25.6571 | soft‑eval =  26.0105 | best =  26.5921 | no_improve = 174 | time = 16s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 3.50e-03
# Epoch  370 | train‑avg =  26.0683 | soft‑eval =  26.0941 | best =  26.5921 | no_improve = 184 | time = 16s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 3.50e-03
# Epoch  380 | train‑avg =  25.8641 | soft‑eval =  25.9763 | best =  26.5921 | no_improve = 194 | time = 17s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 3.50e-03
# Epoch  390 | train‑avg =  25.9674 | soft‑eval =  26.0456 | best =  26.6430 | no_improve =  8 | time = 17s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 3.50e-03
# Epoch  400 | train‑avg =  25.9707 | soft‑eval =  25.9968 | best =  26.6430 | no_improve = 18 | time = 17s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 3.50e-03
# Epoch  410 | train‑avg =  25.9172 | soft‑eval =  26.1529 | best =  26.6430 | no_improve = 28 | time = 18s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 3.50e-03
# Epoch  420 | train‑avg =  26.1621 | soft‑eval =  26.2033 | best =  26.6430 | no_improve = 38 | time = 18s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 3.50e-03
# Epoch  430 | train‑avg =  25.9098 | soft‑eval =  26.1933 | best =  26.6430 | no_improve = 48 | time = 19s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 3.50e-03
# Epoch  440 | train‑avg =  25.8548 | soft‑eval =  25.7816 | best =  26.6430 | no_improve = 58 | time = 19s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 3.50e-03
# Epoch  450 | train‑avg =  25.6505 | soft‑eval =  25.9127 | best =  26.6430 | no_improve = 68 | time = 20s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 3.50e-03
# Epoch  460 | train‑avg =  25.9190 | soft‑eval =  26.0898 | best =  26.6430 | no_improve = 78 | time = 20s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 3.50e-03
# Epoch  470 | train‑avg =  26.2725 | soft‑eval =  25.7591 | best =  26.6430 | no_improve = 88 | time = 21s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 3.50e-03
# Epoch  480 | train‑avg =  26.1303 | soft‑eval =  26.5152 | best =  26.6430 | no_improve = 98 | time = 21s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 3.50e-03
# Epoch  490 | train‑avg =  25.9569 | soft‑eval =  26.0689 | best =  26.6430 | no_improve = 108 | time = 22s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 3.50e-03
# Epoch  500 | train‑avg =  26.0443 | soft‑eval =  25.6570 | best =  26.6430 | no_improve = 118 | time = 22s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 3.50e-03
# Epoch  510 | train‑avg =  26.0244 | soft‑eval =  26.2347 | best =  26.6430 | no_improve = 128 | time = 23s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 3.50e-03
# Epoch  520 | train‑avg =  26.3908 | soft‑eval =  25.7345 | best =  26.6430 | no_improve = 138 | time = 23s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 3.50e-03
# Epoch  530 | train‑avg =  26.1657 | soft‑eval =  26.1017 | best =  26.6430 | no_improve = 148 | time = 24s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 3.50e-03
# Epoch  540 | train‑avg =  25.5948 | soft‑eval =  26.2395 | best =  26.6430 | no_improve = 158 | time = 24s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 3.50e-03
# Epoch  550 | train‑avg =  26.0814 | soft‑eval =  25.9127 | best =  26.6430 | no_improve = 168 | time = 24s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 3.50e-03
# Epoch  560 | train‑avg =  26.0272 | soft‑eval =  26.3876 | best =  26.6430 | no_improve = 178 | time = 25s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 3.50e-03
# Epoch  570 | train‑avg =  26.0061 | soft‑eval =  25.7717 | best =  26.6430 | no_improve = 188 | time = 25s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 3.50e-03
# Epoch  580 | train‑avg =  26.0625 | soft‑eval =  25.9637 | best =  26.6430 | no_improve = 198 | time = 26s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 3.50e-03
# Early stopping triggered after 582 epochs (26s)
# Best score: 26.642980
# No improvement for 200 epochs
#
# Training completed after 581 epochs
# Total training time: 26s
# Average time per epoch: 0.0s
# Best evaluation score: 26.642980
# Final score: 26.237444
#
# Evaluating final policy...
# Sharp policy price ≈ 26.1018  CI: [26.0849,26.1187] (95% CI)
# Setting up input normalization...
# Starting training with early stopping (patience=200, min_epochs=50)
# Will stop when improvement < 1.00e-02 absolute or < 1.00e-03 relative
# Epoch   10 | train‑avg =  25.2832 | soft‑eval =  25.4113 | best =  24.9286 | no_improve =  0 | time = 0s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch   20 | train‑avg =  25.7471 | soft‑eval =  25.5366 | best =  25.8414 | no_improve =  2 | time = 0s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch   30 | train‑avg =  25.9087 | soft‑eval =  25.6613 | best =  26.0341 | no_improve =  5 | time = 1s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch   40 | train‑avg =  25.7825 | soft‑eval =  25.9535 | best =  26.1355 | no_improve =  2 | time = 1s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch   50 | train‑avg =  25.9714 | soft‑eval =  25.8813 | best =  26.1355 | no_improve = 12 | time = 2s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch   60 | train‑avg =  25.8470 | soft‑eval =  25.7547 | best =  26.2529 | no_improve =  1 | time = 2s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch   70 | train‑avg =  26.2063 | soft‑eval =  26.0070 | best =  26.2978 | no_improve =  5 | time = 3s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch   80 | train‑avg =  25.8311 | soft‑eval =  25.9628 | best =  26.2978 | no_improve = 15 | time = 3s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch   90 | train‑avg =  25.7961 | soft‑eval =  25.9371 | best =  26.2978 | no_improve = 25 | time = 3s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  100 | train‑avg =  25.9421 | soft‑eval =  25.8800 | best =  26.4745 | no_improve =  5 | time = 4s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  110 | train‑avg =  26.0118 | soft‑eval =  25.9481 | best =  26.4745 | no_improve = 15 | time = 4s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  120 | train‑avg =  26.1900 | soft‑eval =  26.2505 | best =  26.4745 | no_improve = 25 | time = 5s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  130 | train‑avg =  26.0468 | soft‑eval =  26.2784 | best =  26.4745 | no_improve = 35 | time = 5s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  140 | train‑avg =  26.1015 | soft‑eval =  26.3237 | best =  26.4745 | no_improve = 45 | time = 6s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  150 | train‑avg =  26.0184 | soft‑eval =  26.0702 | best =  26.4745 | no_improve = 55 | time = 6s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  160 | train‑avg =  26.0639 | soft‑eval =  25.8721 | best =  26.4745 | no_improve = 65 | time = 7s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  170 | train‑avg =  26.0194 | soft‑eval =  25.9514 | best =  26.4745 | no_improve = 75 | time = 7s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  180 | train‑avg =  25.8029 | soft‑eval =  26.2767 | best =  26.4745 | no_improve = 85 | time = 7s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  190 | train‑avg =  25.9178 | soft‑eval =  26.0332 | best =  26.4745 | no_improve = 95 | time = 8s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  200 | train‑avg =  26.0125 | soft‑eval =  25.8551 | best =  26.4745 | no_improve = 105 | time = 8s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  210 | train‑avg =  25.8498 | soft‑eval =  25.6176 | best =  26.4745 | no_improve = 115 | time = 9s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  220 | train‑avg =  26.0655 | soft‑eval =  25.9731 | best =  26.4745 | no_improve = 125 | time = 9s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  230 | train‑avg =  25.8852 | soft‑eval =  25.9981 | best =  26.4745 | no_improve = 135 | time = 10s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  240 | train‑avg =  26.0407 | soft‑eval =  25.8678 | best =  26.4745 | no_improve = 145 | time = 10s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  250 | train‑avg =  25.7205 | soft‑eval =  26.0769 | best =  26.4745 | no_improve = 155 | time = 11s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  260 | train‑avg =  26.2140 | soft‑eval =  26.1257 | best =  26.4745 | no_improve = 165 | time = 11s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  270 | train‑avg =  26.3780 | soft‑eval =  26.0716 | best =  26.4745 | no_improve = 175 | time = 12s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  280 | train‑avg =  25.9011 | soft‑eval =  26.1307 | best =  26.4745 | no_improve = 185 | time = 12s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  290 | train‑avg =  26.1042 | soft‑eval =  26.2403 | best =  26.4745 | no_improve = 195 | time = 13s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Early stopping triggered after 295 epochs (13s)
# Best score: 26.474476
# No improvement for 200 epochs
#
# Training completed after 294 epochs
# Total training time: 13s
# Average time per epoch: 0.0s
# Best evaluation score: 26.474476
# Final score: 25.908619
#
# Evaluating final policy...
# Sharp policy price ≈ 26.0745  CI: [26.0573,26.0917] (95% CI)
# Setting up input normalization...
# Starting training with early stopping (patience=200, min_epochs=50)
# Will stop when improvement < 1.00e-02 absolute or < 1.00e-03 relative
# Epoch   10 | train‑avg =  25.4716 | soft‑eval =  25.2835 | best =  25.0971 | no_improve =  0 | time = 0s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch   20 | train‑avg =  25.9532 | soft‑eval =  25.6217 | best =  26.2314 | no_improve =  0 | time = 0s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch   30 | train‑avg =  25.6878 | soft‑eval =  26.0269 | best =  26.2314 | no_improve = 10 | time = 1s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch   40 | train‑avg =  25.7821 | soft‑eval =  26.0660 | best =  26.2314 | no_improve = 20 | time = 1s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch   50 | train‑avg =  25.9242 | soft‑eval =  25.4212 | best =  26.2314 | no_improve = 30 | time = 2s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch   60 | train‑avg =  25.8990 | soft‑eval =  25.9812 | best =  26.2314 | no_improve = 40 | time = 2s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch   70 | train‑avg =  26.0843 | soft‑eval =  25.9594 | best =  26.2314 | no_improve = 50 | time = 3s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch   80 | train‑avg =  26.1894 | soft‑eval =  26.0917 | best =  26.3320 | no_improve =  1 | time = 3s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch   90 | train‑avg =  25.7192 | soft‑eval =  25.8393 | best =  26.3320 | no_improve = 11 | time = 4s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  100 | train‑avg =  25.8256 | soft‑eval =  25.8845 | best =  26.3726 | no_improve =  4 | time = 4s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  110 | train‑avg =  26.2056 | soft‑eval =  26.1934 | best =  26.3726 | no_improve = 14 | time = 4s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  120 | train‑avg =  26.2627 | soft‑eval =  26.1858 | best =  26.3726 | no_improve = 24 | time = 5s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  130 | train‑avg =  26.0721 | soft‑eval =  26.1286 | best =  26.3726 | no_improve = 34 | time = 5s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  140 | train‑avg =  25.6727 | soft‑eval =  25.5732 | best =  26.5021 | no_improve =  6 | time = 6s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  150 | train‑avg =  25.6364 | soft‑eval =  25.7963 | best =  26.5021 | no_improve = 16 | time = 6s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  160 | train‑avg =  25.8470 | soft‑eval =  26.0314 | best =  26.6582 | no_improve =  7 | time = 7s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  170 | train‑avg =  26.1858 | soft‑eval =  25.9014 | best =  26.6582 | no_improve = 17 | time = 7s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  180 | train‑avg =  25.8572 | soft‑eval =  25.9341 | best =  26.6582 | no_improve = 27 | time = 8s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  190 | train‑avg =  25.6711 | soft‑eval =  26.0701 | best =  26.6582 | no_improve = 37 | time = 8s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  200 | train‑avg =  26.1095 | soft‑eval =  26.2074 | best =  26.6582 | no_improve = 47 | time = 9s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  210 | train‑avg =  25.9474 | soft‑eval =  26.2153 | best =  26.6582 | no_improve = 57 | time = 9s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  220 | train‑avg =  26.1240 | soft‑eval =  25.8718 | best =  26.6582 | no_improve = 67 | time = 10s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  230 | train‑avg =  26.2245 | soft‑eval =  26.0019 | best =  26.6582 | no_improve = 77 | time = 10s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  240 | train‑avg =  26.3106 | soft‑eval =  25.9214 | best =  26.6582 | no_improve = 87 | time = 10s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  250 | train‑avg =  25.7054 | soft‑eval =  25.8557 | best =  26.6582 | no_improve = 97 | time = 11s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  260 | train‑avg =  25.7659 | soft‑eval =  26.3225 | best =  26.6582 | no_improve = 107 | time = 11s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  270 | train‑avg =  26.1066 | soft‑eval =  26.1346 | best =  26.6582 | no_improve = 117 | time = 12s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  280 | train‑avg =  25.7752 | soft‑eval =  26.1244 | best =  26.6582 | no_improve = 127 | time = 12s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  290 | train‑avg =  25.7653 | soft‑eval =  25.7515 | best =  26.6582 | no_improve = 137 | time = 13s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  300 | train‑avg =  26.1131 | soft‑eval =  26.0826 | best =  26.6582 | no_improve = 147 | time = 13s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  310 | train‑avg =  26.0746 | soft‑eval =  26.1213 | best =  26.6582 | no_improve = 157 | time = 14s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  320 | train‑avg =  26.2198 | soft‑eval =  26.1842 | best =  26.6582 | no_improve = 167 | time = 14s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  330 | train‑avg =  25.8700 | soft‑eval =  25.8826 | best =  26.6582 | no_improve = 177 | time = 15s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  340 | train‑avg =  26.1221 | soft‑eval =  25.7983 | best =  26.6582 | no_improve = 187 | time = 15s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  350 | train‑avg =  25.8345 | soft‑eval =  25.7187 | best =  26.6582 | no_improve = 197 | time = 16s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Early stopping triggered after 353 epochs (16s)
# Best score: 26.658182
# No improvement for 200 epochs
#
# Training completed after 352 epochs
# Total training time: 16s
# Average time per epoch: 0.0s
# Best evaluation score: 26.658182
# Final score: 25.901479
#
# Evaluating final policy...
# Sharp policy price ≈ 26.0715  CI: [26.0542,26.0888] (95% CI)
# Setting up input normalization...
# Starting training with early stopping (patience=200, min_epochs=50)
# Will stop when improvement < 1.00e-02 absolute or < 1.00e-03 relative
# Epoch   10 | train‑avg =  25.2749 | soft‑eval =  25.5293 | best =  25.3855 | no_improve =  0 | time = 0s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch   20 | train‑avg =  25.8915 | soft‑eval =  26.2134 | best =  25.9576 | no_improve =  5 | time = 0s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch   30 | train‑avg =  26.0089 | soft‑eval =  26.0973 | best =  26.2376 | no_improve =  3 | time = 1s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch   40 | train‑avg =  25.9258 | soft‑eval =  26.2762 | best =  26.2376 | no_improve = 13 | time = 1s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch   50 | train‑avg =  25.7627 | soft‑eval =  26.1501 | best =  26.2762 | no_improve =  9 | time = 2s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch   60 | train‑avg =  26.0641 | soft‑eval =  25.8995 | best =  26.2762 | no_improve = 19 | time = 2s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch   70 | train‑avg =  25.9424 | soft‑eval =  26.2572 | best =  26.4008 | no_improve =  5 | time = 3s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch   80 | train‑avg =  25.6939 | soft‑eval =  25.8003 | best =  26.4008 | no_improve = 15 | time = 3s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch   90 | train‑avg =  25.7656 | soft‑eval =  26.0138 | best =  26.4008 | no_improve = 25 | time = 4s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  100 | train‑avg =  25.9282 | soft‑eval =  26.0457 | best =  26.4008 | no_improve = 35 | time = 4s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  110 | train‑avg =  25.9655 | soft‑eval =  25.8791 | best =  26.4008 | no_improve = 45 | time = 5s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  120 | train‑avg =  25.8850 | soft‑eval =  25.8396 | best =  26.4008 | no_improve = 55 | time = 5s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  130 | train‑avg =  26.1253 | soft‑eval =  25.9494 | best =  26.4008 | no_improve = 65 | time = 6s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  140 | train‑avg =  25.6294 | soft‑eval =  26.0251 | best =  26.4008 | no_improve = 75 | time = 6s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  150 | train‑avg =  26.1852 | soft‑eval =  25.6984 | best =  26.4008 | no_improve = 85 | time = 7s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  160 | train‑avg =  26.0133 | soft‑eval =  25.8519 | best =  26.4008 | no_improve = 95 | time = 7s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  170 | train‑avg =  25.8182 | soft‑eval =  25.7949 | best =  26.4008 | no_improve = 105 | time = 7s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  180 | train‑avg =  26.0811 | soft‑eval =  25.6944 | best =  26.5303 | no_improve =  7 | time = 8s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  190 | train‑avg =  25.8703 | soft‑eval =  25.8452 | best =  26.5303 | no_improve = 17 | time = 8s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  200 | train‑avg =  25.7458 | soft‑eval =  25.9455 | best =  26.5303 | no_improve = 27 | time = 9s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 3.50e-03
# Epoch  210 | train‑avg =  26.0238 | soft‑eval =  26.2159 | best =  26.6081 | no_improve =  0 | time = 9s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 3.50e-03
# Epoch  220 | train‑avg =  26.3086 | soft‑eval =  26.1309 | best =  26.6081 | no_improve = 10 | time = 10s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 3.50e-03
# Epoch  230 | train‑avg =  26.1309 | soft‑eval =  26.0025 | best =  26.6081 | no_improve = 20 | time = 10s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 3.50e-03
# Epoch  240 | train‑avg =  25.5801 | soft‑eval =  26.1832 | best =  26.6081 | no_improve = 30 | time = 11s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 3.50e-03
# Epoch  250 | train‑avg =  25.9528 | soft‑eval =  25.9573 | best =  26.6081 | no_improve = 40 | time = 11s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 3.50e-03
# Epoch  260 | train‑avg =  26.1419 | soft‑eval =  26.1322 | best =  26.6081 | no_improve = 50 | time = 12s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 3.50e-03
# Epoch  270 | train‑avg =  25.8223 | soft‑eval =  26.4862 | best =  26.6081 | no_improve = 60 | time = 12s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 3.50e-03
# Epoch  280 | train‑avg =  25.7418 | soft‑eval =  25.8741 | best =  26.6081 | no_improve = 70 | time = 13s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 3.50e-03
# Epoch  290 | train‑avg =  26.1820 | soft‑eval =  26.1172 | best =  26.6081 | no_improve = 80 | time = 13s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 3.50e-03
# Epoch  300 | train‑avg =  25.9707 | soft‑eval =  25.7780 | best =  26.6081 | no_improve = 90 | time = 13s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 3.50e-03
# Epoch  310 | train‑avg =  25.7588 | soft‑eval =  26.0023 | best =  26.6081 | no_improve = 100 | time = 14s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 3.50e-03
# Epoch  320 | train‑avg =  25.7093 | soft‑eval =  26.0464 | best =  26.6081 | no_improve = 110 | time = 14s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 3.50e-03
# Epoch  330 | train‑avg =  26.0674 | soft‑eval =  26.2195 | best =  26.6081 | no_improve = 120 | time = 15s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 3.50e-03
# Epoch  340 | train‑avg =  26.3242 | soft‑eval =  25.8816 | best =  26.6081 | no_improve = 130 | time = 15s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 3.50e-03
# Epoch  350 | train‑avg =  26.1379 | soft‑eval =  25.9307 | best =  26.6081 | no_improve = 140 | time = 16s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 3.50e-03
# Epoch  360 | train‑avg =  25.8748 | soft‑eval =  26.2770 | best =  26.6081 | no_improve = 150 | time = 16s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 3.50e-03
# Epoch  370 | train‑avg =  25.7354 | soft‑eval =  26.1199 | best =  26.6081 | no_improve = 160 | time = 17s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 3.50e-03
# Epoch  380 | train‑avg =  25.9744 | soft‑eval =  26.1671 | best =  26.6081 | no_improve = 170 | time = 17s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 3.50e-03
# Epoch  390 | train‑avg =  26.1398 | soft‑eval =  25.8721 | best =  26.6970 | no_improve =  4 | time = 18s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 3.50e-03
# Epoch  400 | train‑avg =  26.1807 | soft‑eval =  25.9017 | best =  26.6970 | no_improve = 14 | time = 18s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 3.50e-03
# Epoch  410 | train‑avg =  26.2405 | soft‑eval =  26.1475 | best =  26.6970 | no_improve = 24 | time = 19s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 3.50e-03
# Epoch  420 | train‑avg =  26.0554 | soft‑eval =  26.1835 | best =  26.6970 | no_improve = 34 | time = 19s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 3.50e-03
# Epoch  430 | train‑avg =  26.1610 | soft‑eval =  25.9848 | best =  26.6970 | no_improve = 44 | time = 20s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 1.75e-03
# Epoch  440 | train‑avg =  25.9477 | soft‑eval =  25.9592 | best =  26.6970 | no_improve = 54 | time = 20s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 1.75e-03
# Epoch  450 | train‑avg =  26.1539 | soft‑eval =  25.8939 | best =  26.6970 | no_improve = 64 | time = 21s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 1.75e-03
# Epoch  460 | train‑avg =  26.0350 | soft‑eval =  25.6750 | best =  26.6970 | no_improve = 74 | time = 21s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 1.75e-03
# Epoch  470 | train‑avg =  26.0855 | soft‑eval =  25.8141 | best =  26.6970 | no_improve = 84 | time = 22s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 1.75e-03
# Epoch  480 | train‑avg =  26.2673 | soft‑eval =  25.9464 | best =  26.6970 | no_improve = 94 | time = 22s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 1.75e-03
# Epoch  490 | train‑avg =  26.3563 | soft‑eval =  25.9427 | best =  26.6970 | no_improve = 104 | time = 22s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 1.75e-03
# Epoch  500 | train‑avg =  25.9251 | soft‑eval =  25.9225 | best =  26.6970 | no_improve = 114 | time = 23s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 1.75e-03
# Epoch  510 | train‑avg =  26.1557 | soft‑eval =  26.0513 | best =  26.6970 | no_improve = 124 | time = 23s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 1.75e-03
# Epoch  520 | train‑avg =  26.0491 | soft‑eval =  25.9232 | best =  26.6970 | no_improve = 134 | time = 24s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 1.75e-03
# Epoch  530 | train‑avg =  26.1419 | soft‑eval =  26.2745 | best =  26.6970 | no_improve = 144 | time = 24s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 1.75e-03
# Epoch  540 | train‑avg =  25.9959 | soft‑eval =  26.2169 | best =  26.6970 | no_improve = 154 | time = 25s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 1.75e-03
# Epoch  550 | train‑avg =  25.8306 | soft‑eval =  25.9200 | best =  26.6970 | no_improve = 164 | time = 25s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 1.75e-03
# Epoch  560 | train‑avg =  26.0406 | soft‑eval =  25.9258 | best =  26.6970 | no_improve = 174 | time = 26s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 1.75e-03
# Epoch  570 | train‑avg =  26.4042 | soft‑eval =  25.8987 | best =  26.6970 | no_improve = 184 | time = 26s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 1.75e-03
# Epoch  580 | train‑avg =  26.2384 | soft‑eval =  25.9888 | best =  26.6970 | no_improve = 194 | time = 26s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 1.75e-03
# Early stopping triggered after 586 epochs (27s)
# Best score: 26.696974
# No improvement for 200 epochs
#
# Training completed after 585 epochs
# Total training time: 27s
# Average time per epoch: 0.0s
# Best evaluation score: 26.696974
# Final score: 25.885818
#
# Evaluating final policy...
# Sharp policy price ≈ 26.0958  CI: [26.0785,26.1131] (95% CI)
# Setting up input normalization...
# Starting training with early stopping (patience=200, min_epochs=50)
# Will stop when improvement < 1.00e-02 absolute or < 1.00e-03 relative
# Epoch   10 | train‑avg =  25.3984 | soft‑eval =  25.7994 | best =  25.0919 | no_improve =  0 | time = 0s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch   20 | train‑avg =  25.9887 | soft‑eval =  26.2101 | best =  26.1444 | no_improve =  0 | time = 0s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch   30 | train‑avg =  25.8136 | soft‑eval =  25.9157 | best =  26.2101 | no_improve =  9 | time = 1s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch   40 | train‑avg =  25.8365 | soft‑eval =  25.9589 | best =  26.2101 | no_improve = 19 | time = 1s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch   50 | train‑avg =  25.7352 | soft‑eval =  25.6984 | best =  26.3718 | no_improve =  0 | time = 2s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch   60 | train‑avg =  25.6105 | soft‑eval =  25.7800 | best =  26.3718 | no_improve = 10 | time = 2s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch   70 | train‑avg =  25.6415 | soft‑eval =  25.7921 | best =  26.3718 | no_improve = 20 | time = 3s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch   80 | train‑avg =  26.2738 | soft‑eval =  26.0254 | best =  26.3718 | no_improve = 30 | time = 3s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch   90 | train‑avg =  26.1512 | soft‑eval =  26.5200 | best =  26.3718 | no_improve = 40 | time = 4s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  100 | train‑avg =  26.0153 | soft‑eval =  26.1731 | best =  26.5200 | no_improve =  9 | time = 4s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  110 | train‑avg =  25.6953 | soft‑eval =  26.0476 | best =  26.5200 | no_improve = 19 | time = 4s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  120 | train‑avg =  26.2545 | soft‑eval =  25.9000 | best =  26.5200 | no_improve = 29 | time = 5s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  130 | train‑avg =  26.1403 | soft‑eval =  26.1200 | best =  26.5200 | no_improve = 39 | time = 5s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  140 | train‑avg =  25.9210 | soft‑eval =  25.7745 | best =  26.5200 | no_improve = 49 | time = 6s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  150 | train‑avg =  25.7391 | soft‑eval =  25.8602 | best =  26.5200 | no_improve = 59 | time = 6s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  160 | train‑avg =  26.2042 | soft‑eval =  25.8047 | best =  26.5200 | no_improve = 69 | time = 7s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  170 | train‑avg =  25.9666 | soft‑eval =  26.1584 | best =  26.5200 | no_improve = 79 | time = 7s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  180 | train‑avg =  26.2240 | soft‑eval =  25.7777 | best =  26.5200 | no_improve = 89 | time = 8s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  190 | train‑avg =  26.0325 | soft‑eval =  26.0685 | best =  26.5200 | no_improve = 99 | time = 8s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  200 | train‑avg =  26.1194 | soft‑eval =  26.0920 | best =  26.5200 | no_improve = 109 | time = 8s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  210 | train‑avg =  26.2077 | soft‑eval =  25.8155 | best =  26.5200 | no_improve = 119 | time = 9s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  220 | train‑avg =  26.1851 | soft‑eval =  26.4413 | best =  26.5200 | no_improve = 129 | time = 9s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  230 | train‑avg =  26.0830 | soft‑eval =  26.1205 | best =  26.5200 | no_improve = 139 | time = 10s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  240 | train‑avg =  25.8743 | soft‑eval =  26.1423 | best =  26.5200 | no_improve = 149 | time = 10s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  250 | train‑avg =  26.1713 | soft‑eval =  26.0536 | best =  26.5200 | no_improve = 159 | time = 11s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 3.50e-03
# Epoch  260 | train‑avg =  25.9192 | soft‑eval =  25.8876 | best =  26.5200 | no_improve = 169 | time = 11s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 3.50e-03
# Epoch  270 | train‑avg =  25.9280 | soft‑eval =  26.1966 | best =  26.5200 | no_improve = 179 | time = 12s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 3.50e-03
# Epoch  280 | train‑avg =  26.0898 | soft‑eval =  25.8987 | best =  26.5200 | no_improve = 189 | time = 12s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 3.50e-03
# Epoch  290 | train‑avg =  26.0336 | soft‑eval =  25.9867 | best =  26.5200 | no_improve = 199 | time = 12s | epoch_time = 0.0s | soft_sigma = 2.000 | lr = 3.50e-03
# Early stopping triggered after 291 epochs (12s)
# Best score: 26.519966
# No improvement for 200 epochs
#
# Training completed after 290 epochs
# Total training time: 12s
# Average time per epoch: 0.0s
# Best evaluation score: 26.519966
# Final score: 25.986679
#
# Evaluating final policy...
# Sharp policy price ≈ 26.0934  CI: [26.0765,26.1103] (95% CI)

# %%
print(f"Price = {np.mean(prices):.3f} ({np.std(prices):.3f})")
print(f"Max Price = {np.max(prices):.3f}")
print(f"Times = {times}")
# Out:
# Price = 26.092 (0.012)
# Max Price = 26.111
# Times = ['21s', '20s', '21s', '26s', '13s', '16s', '27s', '12s']

# %%
times = ['21s', '20s', '21s', '26s', '13s', '16s', '27s', '12s']
print(f"Average training time = {average_time_in_seconds(times)}")
# Out:
# Average training time = 19.5

# %% [markdown]
# # d = 10

# %%
d = 10
seed = 42

net, train_hist, eval_hist = train_net(
    soft_sigma=2.0,
    N_train=10_000,
    batch=500,
    lr=0.007,
    seed=seed + trial,
    eval_every=10,
    width=64,
    depth=2,
    dropout=0.1,
    curriculum=False,
    patience=200,            
    min_delta=1e-2,      
    relative_threshold=1e-3,
    min_epochs=50,         
    max_epochs=2000     
)

print("\nEvaluating final policy...")
sharp_mean, sharp_se = evaluate_sharp_policy(net, N_eval=1_000_000)
print(f"Sharp policy price ≈ {sharp_mean:.4f}  CI: [{sharp_mean - 1.96*sharp_se:.4f},{sharp_mean + 1.96*sharp_se:.4f}] (95% CI)")

if len(eval_hist) > 0:
    epochs, scores = zip(*eval_hist)
    plt.figure(figsize=(10, 6))
    plt.plot(epochs, scores, 'b-', linewidth=2, label='Evaluation Score')
    plt.axhline(y=max(scores), color='r', linestyle='--', alpha=0.7, label=f'Best Score: {max(scores):.4f}')
    plt.xlabel('Epoch')
    plt.ylabel('Policy Value')
    plt.title('Training Progress')
    plt.legend()
    plt.grid(True, alpha=0.3)
    plt.show()
# Out:
# Training with early stopping...
# Setting up input normalization...
# Starting training with early stopping (patience=200, min_epochs=50)
# Will stop when improvement < 1.00e-02 absolute or < 1.00e-03 relative
# Epoch   10 | train‑avg =  35.9539 | soft‑eval =  35.9936 | best =  35.7872 | no_improve =  1 | time = 0s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch   20 | train‑avg =  37.7155 | soft‑eval =  37.8466 | best =  37.7485 | no_improve =  1 | time = 1s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch   30 | train‑avg =  37.7644 | soft‑eval =  37.6760 | best =  38.2192 | no_improve =  0 | time = 2s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch   40 | train‑avg =  37.8519 | soft‑eval =  37.9669 | best =  38.2192 | no_improve = 10 | time = 3s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch   50 | train‑avg =  37.7776 | soft‑eval =  37.9302 | best =  38.2192 | no_improve = 20 | time = 4s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch   60 | train‑avg =  37.7558 | soft‑eval =  37.8700 | best =  38.2192 | no_improve = 30 | time = 4s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch   70 | train‑avg =  37.7808 | soft‑eval =  37.4453 | best =  38.2192 | no_improve = 40 | time = 5s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch   80 | train‑avg =  38.0111 | soft‑eval =  37.5862 | best =  38.3295 | no_improve =  8 | time = 6s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch   90 | train‑avg =  37.8632 | soft‑eval =  37.7282 | best =  38.3295 | no_improve = 18 | time = 7s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  100 | train‑avg =  37.6939 | soft‑eval =  38.3048 | best =  38.3831 | no_improve =  6 | time = 8s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  110 | train‑avg =  37.6872 | soft‑eval =  37.8619 | best =  38.3831 | no_improve = 16 | time = 8s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  120 | train‑avg =  37.8392 | soft‑eval =  38.4639 | best =  38.3831 | no_improve = 26 | time = 9s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  130 | train‑avg =  38.0985 | soft‑eval =  37.9360 | best =  38.4639 | no_improve =  9 | time = 10s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  140 | train‑avg =  37.9549 | soft‑eval =  38.2740 | best =  38.4639 | no_improve = 19 | time = 11s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  150 | train‑avg =  38.1950 | soft‑eval =  38.0685 | best =  38.4639 | no_improve = 29 | time = 12s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  160 | train‑avg =  37.9206 | soft‑eval =  38.3511 | best =  38.4639 | no_improve = 39 | time = 12s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  170 | train‑avg =  38.2704 | soft‑eval =  37.9327 | best =  38.5145 | no_improve =  8 | time = 13s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  180 | train‑avg =  38.1723 | soft‑eval =  37.9584 | best =  38.5145 | no_improve = 18 | time = 14s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  190 | train‑avg =  38.1942 | soft‑eval =  38.0962 | best =  38.5145 | no_improve = 28 | time = 15s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  200 | train‑avg =  37.6534 | soft‑eval =  37.6536 | best =  38.5145 | no_improve = 38 | time = 15s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  210 | train‑avg =  38.1543 | soft‑eval =  38.1713 | best =  38.5145 | no_improve = 48 | time = 16s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  220 | train‑avg =  37.9092 | soft‑eval =  37.8730 | best =  38.5145 | no_improve = 58 | time = 17s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  230 | train‑avg =  37.7749 | soft‑eval =  37.8775 | best =  38.5145 | no_improve = 68 | time = 18s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  240 | train‑avg =  38.2050 | soft‑eval =  37.8120 | best =  38.5145 | no_improve = 78 | time = 19s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  250 | train‑avg =  37.7144 | soft‑eval =  38.2852 | best =  38.5145 | no_improve = 88 | time = 19s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  260 | train‑avg =  38.5281 | soft‑eval =  38.0291 | best =  38.5145 | no_improve = 98 | time = 20s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  270 | train‑avg =  37.9021 | soft‑eval =  37.7101 | best =  38.5145 | no_improve = 108 | time = 21s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  280 | train‑avg =  37.9580 | soft‑eval =  38.0230 | best =  38.5145 | no_improve = 118 | time = 22s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 3.50e-03
# Epoch  290 | train‑avg =  38.4646 | soft‑eval =  38.3032 | best =  38.5145 | no_improve = 128 | time = 22s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 3.50e-03
# Epoch  300 | train‑avg =  37.8819 | soft‑eval =  38.2642 | best =  38.5145 | no_improve = 138 | time = 23s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 3.50e-03
# Epoch  310 | train‑avg =  38.2454 | soft‑eval =  38.5218 | best =  38.5145 | no_improve = 148 | time = 24s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 3.50e-03
# Epoch  320 | train‑avg =  38.3335 | soft‑eval =  37.9210 | best =  38.5145 | no_improve = 158 | time = 25s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 3.50e-03
# Epoch  330 | train‑avg =  37.8402 | soft‑eval =  37.5933 | best =  38.5145 | no_improve = 168 | time = 26s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 3.50e-03
# Epoch  340 | train‑avg =  38.4289 | soft‑eval =  37.9175 | best =  38.5145 | no_improve = 178 | time = 26s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 3.50e-03
# Epoch  350 | train‑avg =  38.2348 | soft‑eval =  38.3894 | best =  38.5145 | no_improve = 188 | time = 27s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 3.50e-03
# Epoch  360 | train‑avg =  37.9341 | soft‑eval =  37.9410 | best =  38.5145 | no_improve = 198 | time = 28s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 3.50e-03
# Early stopping triggered after 362 epochs (28s)
# Best score: 38.514531
# No improvement for 200 epochs
#
# Training completed after 361 epochs
# Total training time: 28s
# Average time per epoch: 0.1s
# Best evaluation score: 38.514531
# Final score: 38.338626
#
# Evaluating final policy...
# Sharp policy price ≈ 38.1699  CI: [38.1276,38.2122] (95% CI)

# %%
d = 10
seed = 42

prices = []
times = []
n_trials = 8

for trial in range(n_trials):
    net, train_hist, eval_hist, training_time = train_net(
    soft_sigma=2.0,
    N_train=10_000,
    batch=500,
    lr=0.007,
    seed=seed + trial,
    eval_every=10,
    width=64,
    depth=2,
    dropout=0.1,
    curriculum=False,
    # Early stopping parameters
    patience=200,            
    min_delta=1e-2,      
    relative_threshold=1e-3,
    min_epochs=50,         
    max_epochs=2000     
    )
    times.append(training_time)

    print("\nEvaluating final policy...")
    sharp_mean, sharp_se = evaluate_sharp_policy(net, N_eval=5_000_000)
    prices.append(sharp_mean)
    print(f"Sharp policy price ≈ {sharp_mean:.4f}  CI: [{sharp_mean - 1.96*sharp_se:.4f},{sharp_mean + 1.96*sharp_se:.4f}] (95% CI)")
# Out:
# Setting up input normalization...
# Starting training with early stopping (patience=200, min_epochs=50)
# Will stop when improvement < 1.00e-02 absolute or < 1.00e-03 relative
# Epoch   10 | train‑avg =  35.9539 | soft‑eval =  35.9936 | best =  35.7872 | no_improve =  1 | time = 0s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch   20 | train‑avg =  37.7155 | soft‑eval =  37.8466 | best =  37.7485 | no_improve =  1 | time = 1s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch   30 | train‑avg =  37.7644 | soft‑eval =  37.6760 | best =  38.2192 | no_improve =  0 | time = 2s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch   40 | train‑avg =  37.8519 | soft‑eval =  37.9669 | best =  38.2192 | no_improve = 10 | time = 3s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch   50 | train‑avg =  37.7776 | soft‑eval =  37.9302 | best =  38.2192 | no_improve = 20 | time = 4s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch   60 | train‑avg =  37.7558 | soft‑eval =  37.8700 | best =  38.2192 | no_improve = 30 | time = 5s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch   70 | train‑avg =  37.7808 | soft‑eval =  37.4453 | best =  38.2192 | no_improve = 40 | time = 5s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch   80 | train‑avg =  38.0111 | soft‑eval =  37.5862 | best =  38.3295 | no_improve =  8 | time = 6s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch   90 | train‑avg =  37.8632 | soft‑eval =  37.7282 | best =  38.3295 | no_improve = 18 | time = 7s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  100 | train‑avg =  37.6939 | soft‑eval =  38.3048 | best =  38.3831 | no_improve =  6 | time = 8s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  110 | train‑avg =  37.6872 | soft‑eval =  37.8619 | best =  38.3831 | no_improve = 16 | time = 9s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  120 | train‑avg =  37.8392 | soft‑eval =  38.4639 | best =  38.3831 | no_improve = 26 | time = 10s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  130 | train‑avg =  38.0985 | soft‑eval =  37.9360 | best =  38.4639 | no_improve =  9 | time = 11s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  140 | train‑avg =  37.9549 | soft‑eval =  38.2740 | best =  38.4639 | no_improve = 19 | time = 12s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  150 | train‑avg =  38.1950 | soft‑eval =  38.0685 | best =  38.4639 | no_improve = 29 | time = 12s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  160 | train‑avg =  37.9206 | soft‑eval =  38.3511 | best =  38.4639 | no_improve = 39 | time = 13s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  170 | train‑avg =  38.2704 | soft‑eval =  37.9327 | best =  38.5145 | no_improve =  8 | time = 14s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  180 | train‑avg =  38.1723 | soft‑eval =  37.9584 | best =  38.5145 | no_improve = 18 | time = 15s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  190 | train‑avg =  38.1942 | soft‑eval =  38.0962 | best =  38.5145 | no_improve = 28 | time = 16s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  200 | train‑avg =  37.6534 | soft‑eval =  37.6536 | best =  38.5145 | no_improve = 38 | time = 17s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  210 | train‑avg =  38.1543 | soft‑eval =  38.1713 | best =  38.5145 | no_improve = 48 | time = 18s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  220 | train‑avg =  37.9092 | soft‑eval =  37.8730 | best =  38.5145 | no_improve = 58 | time = 19s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  230 | train‑avg =  37.7749 | soft‑eval =  37.8775 | best =  38.5145 | no_improve = 68 | time = 19s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  240 | train‑avg =  38.2050 | soft‑eval =  37.8120 | best =  38.5145 | no_improve = 78 | time = 20s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  250 | train‑avg =  37.7144 | soft‑eval =  38.2852 | best =  38.5145 | no_improve = 88 | time = 21s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  260 | train‑avg =  38.5281 | soft‑eval =  38.0291 | best =  38.5145 | no_improve = 98 | time = 22s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  270 | train‑avg =  37.9021 | soft‑eval =  37.7101 | best =  38.5145 | no_improve = 108 | time = 23s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  280 | train‑avg =  37.9580 | soft‑eval =  38.0230 | best =  38.5145 | no_improve = 118 | time = 24s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 3.50e-03
# Epoch  290 | train‑avg =  38.4646 | soft‑eval =  38.3032 | best =  38.5145 | no_improve = 128 | time = 25s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 3.50e-03
# Epoch  300 | train‑avg =  37.8819 | soft‑eval =  38.2642 | best =  38.5145 | no_improve = 138 | time = 26s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 3.50e-03
# Epoch  310 | train‑avg =  38.2454 | soft‑eval =  38.5218 | best =  38.5145 | no_improve = 148 | time = 26s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 3.50e-03
# Epoch  320 | train‑avg =  38.3335 | soft‑eval =  37.9210 | best =  38.5145 | no_improve = 158 | time = 27s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 3.50e-03
# Epoch  330 | train‑avg =  37.8402 | soft‑eval =  37.5933 | best =  38.5145 | no_improve = 168 | time = 28s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 3.50e-03
# Epoch  340 | train‑avg =  38.4289 | soft‑eval =  37.9175 | best =  38.5145 | no_improve = 178 | time = 29s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 3.50e-03
# Epoch  350 | train‑avg =  38.2348 | soft‑eval =  38.3894 | best =  38.5145 | no_improve = 188 | time = 30s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 3.50e-03
# Epoch  360 | train‑avg =  37.9341 | soft‑eval =  37.9410 | best =  38.5145 | no_improve = 198 | time = 31s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 3.50e-03
# Early stopping triggered after 362 epochs (31s)
# Best score: 38.514531
# No improvement for 200 epochs
#
# Training completed after 361 epochs
# Total training time: 31s
# Average time per epoch: 0.1s
# Best evaluation score: 38.514531
# Final score: 38.338626
#
# Evaluating final policy...
# Sharp policy price ≈ 38.1714  CI: [38.1525,38.1903] (95% CI)
# Setting up input normalization...
# Starting training with early stopping (patience=200, min_epochs=50)
# Will stop when improvement < 1.00e-02 absolute or < 1.00e-03 relative
# Epoch   10 | train‑avg =  36.6047 | soft‑eval =  36.5045 | best =  35.8761 | no_improve =  0 | time = 0s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch   20 | train‑avg =  37.6463 | soft‑eval =  37.8945 | best =  37.6822 | no_improve =  3 | time = 1s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch   30 | train‑avg =  37.3732 | soft‑eval =  37.3941 | best =  38.2499 | no_improve =  0 | time = 2s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch   40 | train‑avg =  37.6288 | soft‑eval =  37.8533 | best =  38.2499 | no_improve = 10 | time = 3s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch   50 | train‑avg =  37.9556 | soft‑eval =  37.7969 | best =  38.2499 | no_improve = 20 | time = 4s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch   60 | train‑avg =  37.6229 | soft‑eval =  37.7348 | best =  38.2499 | no_improve = 30 | time = 5s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch   70 | train‑avg =  37.7506 | soft‑eval =  37.8298 | best =  38.2499 | no_improve = 40 | time = 5s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch   80 | train‑avg =  37.9124 | soft‑eval =  37.7431 | best =  38.2499 | no_improve = 50 | time = 7s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch   90 | train‑avg =  37.6839 | soft‑eval =  37.8276 | best =  38.2499 | no_improve = 60 | time = 7s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  100 | train‑avg =  37.8052 | soft‑eval =  38.1844 | best =  38.2499 | no_improve = 70 | time = 8s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  110 | train‑avg =  37.8965 | soft‑eval =  37.7849 | best =  38.3908 | no_improve =  6 | time = 9s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  120 | train‑avg =  38.0070 | soft‑eval =  38.1601 | best =  38.3908 | no_improve = 16 | time = 10s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  130 | train‑avg =  38.0791 | soft‑eval =  38.1407 | best =  38.3908 | no_improve = 26 | time = 11s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  140 | train‑avg =  38.3129 | soft‑eval =  37.7905 | best =  38.3908 | no_improve = 36 | time = 12s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  150 | train‑avg =  38.0178 | soft‑eval =  37.7667 | best =  38.4411 | no_improve =  5 | time = 13s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  160 | train‑avg =  37.8530 | soft‑eval =  37.9537 | best =  38.4411 | no_improve = 15 | time = 13s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  170 | train‑avg =  38.1246 | soft‑eval =  37.7289 | best =  38.4411 | no_improve = 25 | time = 14s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  180 | train‑avg =  37.6097 | soft‑eval =  37.7120 | best =  38.4411 | no_improve = 35 | time = 15s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  190 | train‑avg =  37.8979 | soft‑eval =  38.1735 | best =  38.4411 | no_improve = 45 | time = 16s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  200 | train‑avg =  37.8129 | soft‑eval =  37.8338 | best =  38.4411 | no_improve = 55 | time = 17s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  210 | train‑avg =  37.9900 | soft‑eval =  37.7910 | best =  38.4411 | no_improve = 65 | time = 18s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  220 | train‑avg =  37.9282 | soft‑eval =  38.2365 | best =  38.4411 | no_improve = 75 | time = 19s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  230 | train‑avg =  37.7198 | soft‑eval =  38.2286 | best =  38.4411 | no_improve = 85 | time = 19s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  240 | train‑avg =  38.0934 | soft‑eval =  38.3049 | best =  38.5551 | no_improve =  7 | time = 20s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  250 | train‑avg =  37.7901 | soft‑eval =  37.9596 | best =  38.5551 | no_improve = 17 | time = 21s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  260 | train‑avg =  38.1868 | soft‑eval =  38.2979 | best =  38.5551 | no_improve = 27 | time = 22s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  270 | train‑avg =  38.3752 | soft‑eval =  38.1492 | best =  38.5551 | no_improve = 37 | time = 23s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  280 | train‑avg =  37.7284 | soft‑eval =  38.0685 | best =  38.5551 | no_improve = 47 | time = 23s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  290 | train‑avg =  37.7203 | soft‑eval =  37.8591 | best =  38.5551 | no_improve = 57 | time = 24s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  300 | train‑avg =  38.1794 | soft‑eval =  37.8943 | best =  38.5551 | no_improve = 67 | time = 25s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  310 | train‑avg =  38.1470 | soft‑eval =  38.1323 | best =  38.5551 | no_improve = 77 | time = 26s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  320 | train‑avg =  37.7877 | soft‑eval =  38.0205 | best =  38.5551 | no_improve = 87 | time = 27s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  330 | train‑avg =  38.0832 | soft‑eval =  37.9971 | best =  38.8391 | no_improve =  6 | time = 28s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  340 | train‑avg =  38.1203 | soft‑eval =  38.1334 | best =  38.8391 | no_improve = 16 | time = 29s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  350 | train‑avg =  38.5534 | soft‑eval =  38.2432 | best =  38.8391 | no_improve = 26 | time = 30s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  360 | train‑avg =  37.9284 | soft‑eval =  38.4262 | best =  38.8391 | no_improve = 36 | time = 30s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  370 | train‑avg =  38.1559 | soft‑eval =  38.0399 | best =  38.8391 | no_improve = 46 | time = 31s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  380 | train‑avg =  38.4213 | soft‑eval =  37.9860 | best =  38.8391 | no_improve = 56 | time = 32s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  390 | train‑avg =  37.9461 | soft‑eval =  38.3621 | best =  38.8391 | no_improve = 66 | time = 33s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  400 | train‑avg =  38.0012 | soft‑eval =  38.1616 | best =  38.8391 | no_improve = 76 | time = 34s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  410 | train‑avg =  37.8958 | soft‑eval =  37.9145 | best =  38.8391 | no_improve = 86 | time = 35s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  420 | train‑avg =  37.9037 | soft‑eval =  38.1477 | best =  38.8391 | no_improve = 96 | time = 36s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  430 | train‑avg =  38.3056 | soft‑eval =  37.8968 | best =  38.8391 | no_improve = 106 | time = 36s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  440 | train‑avg =  38.0992 | soft‑eval =  37.8490 | best =  38.8391 | no_improve = 116 | time = 37s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  450 | train‑avg =  37.6607 | soft‑eval =  38.1218 | best =  38.8391 | no_improve = 126 | time = 38s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  460 | train‑avg =  37.9908 | soft‑eval =  37.9890 | best =  38.8391 | no_improve = 136 | time = 39s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  470 | train‑avg =  38.4295 | soft‑eval =  38.0662 | best =  38.8391 | no_improve = 146 | time = 40s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  480 | train‑avg =  37.6464 | soft‑eval =  38.3726 | best =  38.8391 | no_improve = 156 | time = 41s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  490 | train‑avg =  38.2432 | soft‑eval =  37.8875 | best =  38.8391 | no_improve = 166 | time = 42s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  500 | train‑avg =  38.3250 | soft‑eval =  38.0270 | best =  38.8391 | no_improve = 176 | time = 42s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  510 | train‑avg =  38.2850 | soft‑eval =  38.0412 | best =  38.8391 | no_improve = 186 | time = 43s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  520 | train‑avg =  38.1247 | soft‑eval =  38.3349 | best =  38.8391 | no_improve = 196 | time = 44s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 3.50e-03
# Early stopping triggered after 524 epochs (45s)
# Best score: 38.839114
# No improvement for 200 epochs
#
# Training completed after 523 epochs
# Total training time: 45s
# Average time per epoch: 0.1s
# Best evaluation score: 38.839114
# Final score: 38.105006
#
# Evaluating final policy...
# Sharp policy price ≈ 38.2158  CI: [38.1967,38.2349] (95% CI)
# Setting up input normalization...
# Starting training with early stopping (patience=200, min_epochs=50)
# Will stop when improvement < 1.00e-02 absolute or < 1.00e-03 relative
# Epoch   10 | train‑avg =  36.2978 | soft‑eval =  36.1642 | best =  35.8709 | no_improve =  0 | time = 0s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch   20 | train‑avg =  37.7843 | soft‑eval =  37.5893 | best =  37.4273 | no_improve =  4 | time = 1s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch   30 | train‑avg =  37.8246 | soft‑eval =  37.4846 | best =  38.2208 | no_improve =  0 | time = 2s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch   40 | train‑avg =  37.6219 | soft‑eval =  37.7060 | best =  38.2208 | no_improve = 10 | time = 3s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch   50 | train‑avg =  37.6886 | soft‑eval =  37.6578 | best =  38.2208 | no_improve = 20 | time = 4s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch   60 | train‑avg =  37.8422 | soft‑eval =  37.3878 | best =  38.2208 | no_improve = 30 | time = 5s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch   70 | train‑avg =  37.9468 | soft‑eval =  38.3113 | best =  38.2208 | no_improve = 40 | time = 5s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch   80 | train‑avg =  37.8484 | soft‑eval =  37.6722 | best =  38.3113 | no_improve =  9 | time = 6s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch   90 | train‑avg =  37.8209 | soft‑eval =  37.5495 | best =  38.3113 | no_improve = 19 | time = 7s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  100 | train‑avg =  37.7241 | soft‑eval =  37.9164 | best =  38.3113 | no_improve = 29 | time = 8s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  110 | train‑avg =  38.1402 | soft‑eval =  37.8293 | best =  38.3113 | no_improve = 39 | time = 9s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  120 | train‑avg =  37.9643 | soft‑eval =  38.0320 | best =  38.3113 | no_improve = 49 | time = 10s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  130 | train‑avg =  37.6217 | soft‑eval =  38.1248 | best =  38.3113 | no_improve = 59 | time = 10s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  140 | train‑avg =  37.3745 | soft‑eval =  37.8292 | best =  38.3113 | no_improve = 69 | time = 11s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  150 | train‑avg =  37.9573 | soft‑eval =  38.1991 | best =  38.5239 | no_improve =  3 | time = 12s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  160 | train‑avg =  38.1440 | soft‑eval =  38.1654 | best =  38.5239 | no_improve = 13 | time = 13s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  170 | train‑avg =  37.9061 | soft‑eval =  37.9867 | best =  38.5239 | no_improve = 23 | time = 14s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  180 | train‑avg =  37.8832 | soft‑eval =  38.2152 | best =  38.5239 | no_improve = 33 | time = 15s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  190 | train‑avg =  37.9031 | soft‑eval =  37.7598 | best =  38.5239 | no_improve = 43 | time = 16s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  200 | train‑avg =  38.2961 | soft‑eval =  38.2801 | best =  38.5239 | no_improve = 53 | time = 16s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  210 | train‑avg =  38.3321 | soft‑eval =  38.1122 | best =  38.5239 | no_improve = 63 | time = 17s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  220 | train‑avg =  38.1743 | soft‑eval =  38.1017 | best =  38.5239 | no_improve = 73 | time = 18s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  230 | train‑avg =  38.2959 | soft‑eval =  38.0057 | best =  38.5239 | no_improve = 83 | time = 19s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 3.50e-03
# Epoch  240 | train‑avg =  38.3512 | soft‑eval =  38.2248 | best =  38.5627 | no_improve =  8 | time = 20s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 3.50e-03
# Epoch  250 | train‑avg =  38.2755 | soft‑eval =  37.7967 | best =  38.5627 | no_improve = 18 | time = 21s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 3.50e-03
# Epoch  260 | train‑avg =  38.0730 | soft‑eval =  38.2174 | best =  38.5627 | no_improve = 28 | time = 21s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 3.50e-03
# Epoch  270 | train‑avg =  37.9257 | soft‑eval =  38.3352 | best =  38.5627 | no_improve = 38 | time = 22s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 3.50e-03
# Epoch  280 | train‑avg =  38.1795 | soft‑eval =  37.8667 | best =  38.5627 | no_improve = 48 | time = 23s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 3.50e-03
# Epoch  290 | train‑avg =  37.9907 | soft‑eval =  37.8528 | best =  38.5627 | no_improve = 58 | time = 24s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 3.50e-03
# Epoch  300 | train‑avg =  37.8854 | soft‑eval =  38.3244 | best =  38.5627 | no_improve = 68 | time = 25s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 3.50e-03
# Epoch  310 | train‑avg =  38.3151 | soft‑eval =  38.0793 | best =  38.5627 | no_improve = 78 | time = 26s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 3.50e-03
# Epoch  320 | train‑avg =  37.8774 | soft‑eval =  38.1424 | best =  38.5627 | no_improve = 88 | time = 27s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 3.50e-03
# Epoch  330 | train‑avg =  37.9277 | soft‑eval =  37.8055 | best =  38.5627 | no_improve = 98 | time = 28s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 3.50e-03
# Epoch  340 | train‑avg =  37.7934 | soft‑eval =  38.3130 | best =  38.5627 | no_improve = 108 | time = 28s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 3.50e-03
# Epoch  350 | train‑avg =  38.1373 | soft‑eval =  38.0788 | best =  38.5627 | no_improve = 118 | time = 29s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 3.50e-03
# Epoch  360 | train‑avg =  38.6086 | soft‑eval =  38.0581 | best =  38.5627 | no_improve = 128 | time = 30s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 3.50e-03
# Epoch  370 | train‑avg =  37.9953 | soft‑eval =  38.3876 | best =  38.5627 | no_improve = 138 | time = 31s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 3.50e-03
# Epoch  380 | train‑avg =  37.9511 | soft‑eval =  38.4344 | best =  38.5627 | no_improve = 148 | time = 32s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 3.50e-03
# Epoch  390 | train‑avg =  38.0183 | soft‑eval =  37.9561 | best =  38.5627 | no_improve = 158 | time = 32s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 3.50e-03
# Epoch  400 | train‑avg =  37.9264 | soft‑eval =  37.8660 | best =  38.5627 | no_improve = 168 | time = 33s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 3.50e-03
# Epoch  410 | train‑avg =  37.7320 | soft‑eval =  37.8873 | best =  38.5627 | no_improve = 178 | time = 34s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 3.50e-03
# Epoch  420 | train‑avg =  37.9170 | soft‑eval =  38.1870 | best =  38.5627 | no_improve = 188 | time = 35s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 3.50e-03
# Epoch  430 | train‑avg =  38.1298 | soft‑eval =  38.1751 | best =  38.5627 | no_improve = 198 | time = 36s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 3.50e-03
# Early stopping triggered after 432 epochs (36s)
# Best score: 38.562703
# No improvement for 200 epochs
#
# Training completed after 431 epochs
# Total training time: 36s
# Average time per epoch: 0.1s
# Best evaluation score: 38.562703
# Final score: 37.950981
#
# Evaluating final policy...
# Sharp policy price ≈ 38.1505  CI: [38.1317,38.1693] (95% CI)
# Setting up input normalization...
# Starting training with early stopping (patience=200, min_epochs=50)
# Will stop when improvement < 1.00e-02 absolute or < 1.00e-03 relative
# Epoch   10 | train‑avg =  35.5887 | soft‑eval =  36.3054 | best =  36.1298 | no_improve =  0 | time = 0s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch   20 | train‑avg =  37.4982 | soft‑eval =  37.6855 | best =  37.3646 | no_improve =  2 | time = 1s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch   30 | train‑avg =  37.6765 | soft‑eval =  37.4012 | best =  37.8779 | no_improve =  1 | time = 2s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch   40 | train‑avg =  37.7351 | soft‑eval =  37.9762 | best =  38.1855 | no_improve =  1 | time = 3s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch   50 | train‑avg =  37.8830 | soft‑eval =  37.6248 | best =  38.1855 | no_improve = 11 | time = 4s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch   60 | train‑avg =  37.9523 | soft‑eval =  37.6527 | best =  38.1855 | no_improve = 21 | time = 5s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch   70 | train‑avg =  37.6059 | soft‑eval =  37.7126 | best =  38.1855 | no_improve = 31 | time = 5s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch   80 | train‑avg =  37.8728 | soft‑eval =  37.8288 | best =  38.3258 | no_improve =  3 | time = 6s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch   90 | train‑avg =  38.1988 | soft‑eval =  37.8638 | best =  38.3258 | no_improve = 13 | time = 7s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  100 | train‑avg =  37.9465 | soft‑eval =  37.9092 | best =  38.3738 | no_improve =  5 | time = 8s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  110 | train‑avg =  37.8521 | soft‑eval =  38.1886 | best =  38.3738 | no_improve = 15 | time = 9s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  120 | train‑avg =  38.0032 | soft‑eval =  37.7247 | best =  38.3738 | no_improve = 25 | time = 9s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  130 | train‑avg =  37.9313 | soft‑eval =  38.0965 | best =  38.3738 | no_improve = 35 | time = 10s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  140 | train‑avg =  37.9451 | soft‑eval =  38.2154 | best =  38.3738 | no_improve = 45 | time = 11s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  150 | train‑avg =  37.9892 | soft‑eval =  37.8826 | best =  38.3738 | no_improve = 55 | time = 12s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  160 | train‑avg =  38.1158 | soft‑eval =  38.0715 | best =  38.3738 | no_improve = 65 | time = 13s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  170 | train‑avg =  37.6467 | soft‑eval =  38.1505 | best =  38.4633 | no_improve =  6 | time = 14s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  180 | train‑avg =  37.7333 | soft‑eval =  37.7876 | best =  38.4633 | no_improve = 16 | time = 15s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  190 | train‑avg =  37.7092 | soft‑eval =  37.8403 | best =  38.4633 | no_improve = 26 | time = 16s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  200 | train‑avg =  37.7814 | soft‑eval =  38.0763 | best =  38.4633 | no_improve = 36 | time = 16s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  210 | train‑avg =  38.2402 | soft‑eval =  37.9542 | best =  38.4633 | no_improve = 46 | time = 17s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  220 | train‑avg =  37.9208 | soft‑eval =  38.0628 | best =  38.4633 | no_improve = 56 | time = 18s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  230 | train‑avg =  38.2605 | soft‑eval =  38.1596 | best =  38.4633 | no_improve = 66 | time = 19s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  240 | train‑avg =  38.3832 | soft‑eval =  38.1482 | best =  38.6531 | no_improve =  8 | time = 20s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  250 | train‑avg =  37.9788 | soft‑eval =  37.6193 | best =  38.6531 | no_improve = 18 | time = 20s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  260 | train‑avg =  38.1478 | soft‑eval =  38.5102 | best =  38.6531 | no_improve = 28 | time = 21s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  270 | train‑avg =  37.7367 | soft‑eval =  38.1418 | best =  38.6531 | no_improve = 38 | time = 22s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  280 | train‑avg =  38.0016 | soft‑eval =  38.5558 | best =  38.6531 | no_improve = 48 | time = 23s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  290 | train‑avg =  38.1432 | soft‑eval =  38.0405 | best =  38.6531 | no_improve = 58 | time = 24s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  300 | train‑avg =  37.8477 | soft‑eval =  38.0112 | best =  38.6531 | no_improve = 68 | time = 25s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  310 | train‑avg =  37.9022 | soft‑eval =  37.9829 | best =  38.6531 | no_improve = 78 | time = 26s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  320 | train‑avg =  38.0177 | soft‑eval =  37.9862 | best =  38.6531 | no_improve = 88 | time = 26s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  330 | train‑avg =  38.1040 | soft‑eval =  38.4537 | best =  38.6531 | no_improve = 98 | time = 27s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  340 | train‑avg =  38.2517 | soft‑eval =  38.4413 | best =  38.6531 | no_improve = 108 | time = 28s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  350 | train‑avg =  38.2219 | soft‑eval =  38.0005 | best =  38.6531 | no_improve = 118 | time = 29s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  360 | train‑avg =  38.1502 | soft‑eval =  38.0576 | best =  38.6531 | no_improve = 128 | time = 30s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  370 | train‑avg =  38.3003 | soft‑eval =  38.2401 | best =  38.6531 | no_improve = 138 | time = 31s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  380 | train‑avg =  38.1131 | soft‑eval =  38.2955 | best =  38.6531 | no_improve = 148 | time = 32s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  390 | train‑avg =  37.7815 | soft‑eval =  38.1547 | best =  38.6531 | no_improve = 158 | time = 32s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  400 | train‑avg =  37.9235 | soft‑eval =  38.2585 | best =  38.6531 | no_improve = 168 | time = 33s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  410 | train‑avg =  38.2227 | soft‑eval =  38.0446 | best =  38.6531 | no_improve = 178 | time = 34s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  420 | train‑avg =  38.0191 | soft‑eval =  38.0990 | best =  38.6531 | no_improve = 188 | time = 35s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  430 | train‑avg =  38.0767 | soft‑eval =  38.0513 | best =  38.6531 | no_improve = 198 | time = 36s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Early stopping triggered after 432 epochs (36s)
# Best score: 38.653086
# No improvement for 200 epochs
#
# Training completed after 431 epochs
# Total training time: 36s
# Average time per epoch: 0.1s
# Best evaluation score: 38.653086
# Final score: 37.845300
#
# Evaluating final policy...
# Sharp policy price ≈ 38.1742  CI: [38.1551,38.1932] (95% CI)
# Setting up input normalization...
# Starting training with early stopping (patience=200, min_epochs=50)
# Will stop when improvement < 1.00e-02 absolute or < 1.00e-03 relative
# Epoch   10 | train‑avg =  36.0294 | soft‑eval =  35.9957 | best =  35.9584 | no_improve =  0 | time = 0s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch   20 | train‑avg =  37.9198 | soft‑eval =  37.7005 | best =  37.6831 | no_improve =  2 | time = 1s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch   30 | train‑avg =  38.0422 | soft‑eval =  37.8753 | best =  37.8790 | no_improve =  7 | time = 2s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch   40 | train‑avg =  37.9379 | soft‑eval =  37.7672 | best =  38.0802 | no_improve =  8 | time = 3s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch   50 | train‑avg =  37.6181 | soft‑eval =  37.6186 | best =  38.1552 | no_improve =  0 | time = 4s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch   60 | train‑avg =  38.0864 | soft‑eval =  37.9464 | best =  38.1552 | no_improve = 10 | time = 5s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch   70 | train‑avg =  38.1336 | soft‑eval =  38.1596 | best =  38.1552 | no_improve = 20 | time = 5s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch   80 | train‑avg =  37.8734 | soft‑eval =  38.2152 | best =  38.1552 | no_improve = 30 | time = 6s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch   90 | train‑avg =  37.8283 | soft‑eval =  38.4040 | best =  38.2152 | no_improve =  9 | time = 7s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  100 | train‑avg =  37.8312 | soft‑eval =  37.9167 | best =  38.4040 | no_improve =  9 | time = 8s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  110 | train‑avg =  37.7636 | soft‑eval =  38.3019 | best =  38.4040 | no_improve = 19 | time = 9s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  120 | train‑avg =  38.3185 | soft‑eval =  37.9024 | best =  38.4040 | no_improve = 29 | time = 10s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  130 | train‑avg =  37.5017 | soft‑eval =  38.3014 | best =  38.4040 | no_improve = 39 | time = 10s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  140 | train‑avg =  37.9160 | soft‑eval =  37.9614 | best =  38.4040 | no_improve = 49 | time = 11s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  150 | train‑avg =  38.2044 | soft‑eval =  37.7863 | best =  38.5626 | no_improve =  3 | time = 12s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  160 | train‑avg =  38.0865 | soft‑eval =  38.3018 | best =  38.5626 | no_improve = 13 | time = 13s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  170 | train‑avg =  38.2424 | soft‑eval =  37.6920 | best =  38.5626 | no_improve = 23 | time = 14s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  180 | train‑avg =  37.8734 | soft‑eval =  37.9498 | best =  38.5626 | no_improve = 33 | time = 15s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  190 | train‑avg =  37.6548 | soft‑eval =  37.9128 | best =  38.5626 | no_improve = 43 | time = 16s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  200 | train‑avg =  37.8007 | soft‑eval =  37.6411 | best =  38.5626 | no_improve = 53 | time = 16s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  210 | train‑avg =  38.1031 | soft‑eval =  38.1030 | best =  38.5626 | no_improve = 63 | time = 17s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  220 | train‑avg =  38.1054 | soft‑eval =  38.0007 | best =  38.5626 | no_improve = 73 | time = 18s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  230 | train‑avg =  38.3981 | soft‑eval =  37.6658 | best =  38.5626 | no_improve = 83 | time = 19s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  240 | train‑avg =  38.3092 | soft‑eval =  37.8240 | best =  38.5626 | no_improve = 93 | time = 20s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  250 | train‑avg =  38.2560 | soft‑eval =  38.0696 | best =  38.5626 | no_improve = 103 | time = 21s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 3.50e-03
# Epoch  260 | train‑avg =  38.0592 | soft‑eval =  37.9977 | best =  38.5626 | no_improve = 113 | time = 22s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 3.50e-03
# Epoch  270 | train‑avg =  38.3595 | soft‑eval =  38.2461 | best =  38.5626 | no_improve = 123 | time = 22s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 3.50e-03
# Epoch  280 | train‑avg =  38.0253 | soft‑eval =  37.6059 | best =  38.5626 | no_improve = 133 | time = 23s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 3.50e-03
# Epoch  290 | train‑avg =  37.9902 | soft‑eval =  38.2372 | best =  38.6033 | no_improve =  6 | time = 24s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 3.50e-03
# Epoch  300 | train‑avg =  37.6134 | soft‑eval =  37.8890 | best =  38.6033 | no_improve = 16 | time = 25s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 3.50e-03
# Epoch  310 | train‑avg =  38.2153 | soft‑eval =  38.0646 | best =  38.6033 | no_improve = 26 | time = 26s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 3.50e-03
# Epoch  320 | train‑avg =  38.0642 | soft‑eval =  38.1853 | best =  38.6033 | no_improve = 36 | time = 26s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 3.50e-03
# Epoch  330 | train‑avg =  37.9132 | soft‑eval =  38.0767 | best =  38.6033 | no_improve = 46 | time = 27s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 3.50e-03
# Epoch  340 | train‑avg =  38.3316 | soft‑eval =  38.5199 | best =  38.6033 | no_improve = 56 | time = 28s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 3.50e-03
# Epoch  350 | train‑avg =  37.8308 | soft‑eval =  38.0054 | best =  38.6033 | no_improve = 66 | time = 29s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 3.50e-03
# Epoch  360 | train‑avg =  38.0461 | soft‑eval =  38.3212 | best =  38.6033 | no_improve = 76 | time = 30s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 3.50e-03
# Epoch  370 | train‑avg =  38.1750 | soft‑eval =  38.2345 | best =  38.6033 | no_improve = 86 | time = 31s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 3.50e-03
# Epoch  380 | train‑avg =  38.4051 | soft‑eval =  38.1649 | best =  38.6033 | no_improve = 96 | time = 32s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 3.50e-03
# Epoch  390 | train‑avg =  38.3040 | soft‑eval =  38.4757 | best =  38.6033 | no_improve = 106 | time = 32s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 3.50e-03
# Epoch  400 | train‑avg =  38.1040 | soft‑eval =  38.3039 | best =  38.6033 | no_improve = 116 | time = 33s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 3.50e-03
# Epoch  410 | train‑avg =  38.1194 | soft‑eval =  38.1169 | best =  38.6033 | no_improve = 126 | time = 34s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 3.50e-03
# Epoch  420 | train‑avg =  37.9883 | soft‑eval =  37.9303 | best =  38.6033 | no_improve = 136 | time = 35s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 3.50e-03
# Epoch  430 | train‑avg =  37.7947 | soft‑eval =  38.0830 | best =  38.6033 | no_improve = 146 | time = 36s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 3.50e-03
# Epoch  440 | train‑avg =  38.1662 | soft‑eval =  38.2372 | best =  38.6033 | no_improve = 156 | time = 37s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 3.50e-03
# Epoch  450 | train‑avg =  38.4207 | soft‑eval =  38.3764 | best =  38.6033 | no_improve = 166 | time = 38s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 3.50e-03
# Epoch  460 | train‑avg =  37.9319 | soft‑eval =  38.4352 | best =  38.6033 | no_improve = 176 | time = 38s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 3.50e-03
# Epoch  470 | train‑avg =  38.0797 | soft‑eval =  38.5002 | best =  38.6033 | no_improve = 186 | time = 39s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 3.50e-03
# Epoch  480 | train‑avg =  38.7635 | soft‑eval =  38.1380 | best =  38.6033 | no_improve = 196 | time = 40s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 3.50e-03
# Early stopping triggered after 484 epochs (41s)
# Best score: 38.603315
# No improvement for 200 epochs
#
# Training completed after 483 epochs
# Total training time: 41s
# Average time per epoch: 0.1s
# Best evaluation score: 38.603315
# Final score: 37.934815
#
# Evaluating final policy...
# Sharp policy price ≈ 38.2193  CI: [38.2007,38.2380] (95% CI)
# Setting up input normalization...
# Starting training with early stopping (patience=200, min_epochs=50)
# Will stop when improvement < 1.00e-02 absolute or < 1.00e-03 relative
# Epoch   10 | train‑avg =  36.2498 | soft‑eval =  35.9373 | best =  35.7133 | no_improve =  0 | time = 0s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch   20 | train‑avg =  37.0805 | soft‑eval =  37.9190 | best =  37.4707 | no_improve =  0 | time = 1s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch   30 | train‑avg =  37.8657 | soft‑eval =  37.7173 | best =  38.0322 | no_improve =  1 | time = 2s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch   40 | train‑avg =  37.7475 | soft‑eval =  37.8703 | best =  38.1542 | no_improve =  4 | time = 3s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch   50 | train‑avg =  37.8353 | soft‑eval =  37.7625 | best =  38.2605 | no_improve =  1 | time = 4s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch   60 | train‑avg =  38.0712 | soft‑eval =  38.0830 | best =  38.2605 | no_improve = 11 | time = 4s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch   70 | train‑avg =  37.8212 | soft‑eval =  37.6443 | best =  38.2605 | no_improve = 21 | time = 5s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch   80 | train‑avg =  38.2661 | soft‑eval =  38.0845 | best =  38.2605 | no_improve = 31 | time = 6s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch   90 | train‑avg =  37.9890 | soft‑eval =  37.7298 | best =  38.3801 | no_improve =  7 | time = 7s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  100 | train‑avg =  37.8806 | soft‑eval =  38.0821 | best =  38.3801 | no_improve = 17 | time = 8s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  110 | train‑avg =  37.9415 | soft‑eval =  37.9498 | best =  38.3801 | no_improve = 27 | time = 9s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  120 | train‑avg =  38.0604 | soft‑eval =  38.2545 | best =  38.3801 | no_improve = 37 | time = 10s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  130 | train‑avg =  37.7548 | soft‑eval =  37.8905 | best =  38.3801 | no_improve = 47 | time = 10s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  140 | train‑avg =  37.5956 | soft‑eval =  37.6771 | best =  38.3801 | no_improve = 57 | time = 11s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  150 | train‑avg =  37.9324 | soft‑eval =  37.8718 | best =  38.3801 | no_improve = 67 | time = 12s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  160 | train‑avg =  38.1636 | soft‑eval =  38.5390 | best =  38.3801 | no_improve = 77 | time = 13s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  170 | train‑avg =  37.9365 | soft‑eval =  37.8260 | best =  38.5390 | no_improve =  9 | time = 14s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  180 | train‑avg =  37.5992 | soft‑eval =  38.2383 | best =  38.5390 | no_improve = 19 | time = 15s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  190 | train‑avg =  37.8500 | soft‑eval =  37.8694 | best =  38.5390 | no_improve = 29 | time = 15s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  200 | train‑avg =  38.3042 | soft‑eval =  37.7896 | best =  38.5390 | no_improve = 39 | time = 16s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  210 | train‑avg =  38.2403 | soft‑eval =  38.1017 | best =  38.5801 | no_improve =  7 | time = 17s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  220 | train‑avg =  38.0161 | soft‑eval =  37.9300 | best =  38.5801 | no_improve = 17 | time = 18s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  230 | train‑avg =  38.2613 | soft‑eval =  38.1432 | best =  38.5801 | no_improve = 27 | time = 19s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  240 | train‑avg =  37.9306 | soft‑eval =  38.2396 | best =  38.5801 | no_improve = 37 | time = 20s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  250 | train‑avg =  37.8390 | soft‑eval =  38.1384 | best =  38.5801 | no_improve = 47 | time = 20s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  260 | train‑avg =  37.9898 | soft‑eval =  38.0626 | best =  38.5801 | no_improve = 57 | time = 21s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  270 | train‑avg =  37.7655 | soft‑eval =  37.7970 | best =  38.5801 | no_improve = 67 | time = 22s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  280 | train‑avg =  38.3496 | soft‑eval =  38.0727 | best =  38.5801 | no_improve = 77 | time = 23s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  290 | train‑avg =  38.0172 | soft‑eval =  38.2941 | best =  38.5801 | no_improve = 87 | time = 24s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  300 | train‑avg =  38.6646 | soft‑eval =  38.0405 | best =  38.5801 | no_improve = 97 | time = 25s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  310 | train‑avg =  38.0840 | soft‑eval =  37.9898 | best =  38.5801 | no_improve = 107 | time = 26s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  320 | train‑avg =  38.0350 | soft‑eval =  38.0488 | best =  38.5801 | no_improve = 117 | time = 26s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 3.50e-03
# Epoch  330 | train‑avg =  38.3319 | soft‑eval =  37.9199 | best =  38.5801 | no_improve = 127 | time = 27s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 3.50e-03
# Epoch  340 | train‑avg =  38.1757 | soft‑eval =  38.2325 | best =  38.5801 | no_improve = 137 | time = 28s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 3.50e-03
# Epoch  350 | train‑avg =  37.6712 | soft‑eval =  38.0022 | best =  38.6212 | no_improve =  6 | time = 29s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 3.50e-03
# Epoch  360 | train‑avg =  38.0764 | soft‑eval =  38.2645 | best =  38.7485 | no_improve =  3 | time = 30s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 3.50e-03
# Epoch  370 | train‑avg =  38.2171 | soft‑eval =  37.7806 | best =  38.7485 | no_improve = 13 | time = 31s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 3.50e-03
# Epoch  380 | train‑avg =  38.1892 | soft‑eval =  38.0468 | best =  38.7485 | no_improve = 23 | time = 31s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 3.50e-03
# Epoch  390 | train‑avg =  38.3416 | soft‑eval =  38.0670 | best =  38.7485 | no_improve = 33 | time = 32s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 3.50e-03
# Epoch  400 | train‑avg =  37.7752 | soft‑eval =  38.2073 | best =  38.7485 | no_improve = 43 | time = 33s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 3.50e-03
# Epoch  410 | train‑avg =  37.8748 | soft‑eval =  38.4893 | best =  38.7485 | no_improve = 53 | time = 34s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 3.50e-03
# Epoch  420 | train‑avg =  38.2623 | soft‑eval =  38.3302 | best =  38.7485 | no_improve = 63 | time = 35s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 3.50e-03
# Epoch  430 | train‑avg =  38.0293 | soft‑eval =  37.7781 | best =  38.7485 | no_improve = 73 | time = 36s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 3.50e-03
# Epoch  440 | train‑avg =  38.0508 | soft‑eval =  38.1006 | best =  38.7485 | no_improve = 83 | time = 36s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 3.50e-03
# Epoch  450 | train‑avg =  38.0513 | soft‑eval =  38.2676 | best =  38.7485 | no_improve = 93 | time = 37s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 3.50e-03
# Epoch  460 | train‑avg =  38.4134 | soft‑eval =  38.2262 | best =  38.7485 | no_improve = 103 | time = 38s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 3.50e-03
# Epoch  470 | train‑avg =  38.1806 | soft‑eval =  37.9150 | best =  38.7485 | no_improve = 113 | time = 39s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 3.50e-03
# Epoch  480 | train‑avg =  38.4963 | soft‑eval =  38.3903 | best =  38.8638 | no_improve =  2 | time = 40s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 1.75e-03
# Epoch  490 | train‑avg =  38.4993 | soft‑eval =  37.8963 | best =  38.8638 | no_improve = 12 | time = 41s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 1.75e-03
# Epoch  500 | train‑avg =  38.2347 | soft‑eval =  37.8696 | best =  38.8638 | no_improve = 22 | time = 42s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 1.75e-03
# Epoch  510 | train‑avg =  37.9707 | soft‑eval =  38.1162 | best =  38.8638 | no_improve = 32 | time = 42s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 1.75e-03
# Epoch  520 | train‑avg =  38.0446 | soft‑eval =  37.7413 | best =  38.8638 | no_improve = 42 | time = 43s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 1.75e-03
# Epoch  530 | train‑avg =  37.7414 | soft‑eval =  37.8727 | best =  38.8638 | no_improve = 52 | time = 44s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 1.75e-03
# Epoch  540 | train‑avg =  38.0251 | soft‑eval =  38.0694 | best =  38.8638 | no_improve = 62 | time = 45s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 1.75e-03
# Epoch  550 | train‑avg =  37.9930 | soft‑eval =  38.4285 | best =  38.8638 | no_improve = 72 | time = 46s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 1.75e-03
# ...
# Epoch  670 | train‑avg =  38.1428 | soft‑eval =  38.3950 | best =  38.8638 | no_improve = 192 | time = 56s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 8.75e-04
# Early stopping triggered after 678 epochs (57s)
# Best score: 38.863828
# No improvement for 200 epochs
#
# Training completed after 677 epochs
# Total training time: 57s
# Average time per epoch: 0.1s
# Best evaluation score: 38.863828
# Final score: 38.209422
#
# Evaluating final policy...
# Sharp policy price ≈ 38.2425  CI: [38.2236,38.2613] (95% CI)
# Setting up input normalization...
# Starting training with early stopping (patience=200, min_epochs=50)
# Will stop when improvement < 1.00e-02 absolute or < 1.00e-03 relative
# Epoch   10 | train‑avg =  36.4895 | soft‑eval =  36.3852 | best =  36.1279 | no_improve =  0 | time = 0s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch   20 | train‑avg =  37.8340 | soft‑eval =  37.5554 | best =  37.5281 | no_improve =  0 | time = 1s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch   30 | train‑avg =  37.5734 | soft‑eval =  37.9367 | best =  38.2362 | no_improve =  1 | time = 2s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch   40 | train‑avg =  37.7064 | soft‑eval =  37.7702 | best =  38.2362 | no_improve = 11 | time = 3s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch   50 | train‑avg =  37.5900 | soft‑eval =  37.8368 | best =  38.3605 | no_improve =  3 | time = 4s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch   60 | train‑avg =  37.8529 | soft‑eval =  37.7190 | best =  38.3605 | no_improve = 13 | time = 4s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch   70 | train‑avg =  38.0818 | soft‑eval =  37.7745 | best =  38.3605 | no_improve = 23 | time = 5s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch   80 | train‑avg =  38.0297 | soft‑eval =  38.1012 | best =  38.3605 | no_improve = 33 | time = 6s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch   90 | train‑avg =  37.6826 | soft‑eval =  37.8053 | best =  38.3605 | no_improve = 43 | time = 7s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  100 | train‑avg =  37.8899 | soft‑eval =  37.7059 | best =  38.3605 | no_improve = 53 | time = 8s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  110 | train‑avg =  37.7231 | soft‑eval =  38.2263 | best =  38.5311 | no_improve =  4 | time = 8s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  120 | train‑avg =  37.9660 | soft‑eval =  37.8851 | best =  38.5311 | no_improve = 14 | time = 9s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  130 | train‑avg =  38.2027 | soft‑eval =  38.4416 | best =  38.5311 | no_improve = 24 | time = 10s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  140 | train‑avg =  38.1475 | soft‑eval =  37.8411 | best =  38.5311 | no_improve = 34 | time = 11s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  150 | train‑avg =  38.3977 | soft‑eval =  38.0930 | best =  38.5311 | no_improve = 44 | time = 12s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  160 | train‑avg =  38.0619 | soft‑eval =  37.6078 | best =  38.5311 | no_improve = 54 | time = 13s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  170 | train‑avg =  37.9478 | soft‑eval =  38.0584 | best =  38.5311 | no_improve = 64 | time = 14s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  180 | train‑avg =  38.0441 | soft‑eval =  38.1078 | best =  38.5311 | no_improve = 74 | time = 14s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  190 | train‑avg =  38.0272 | soft‑eval =  38.2987 | best =  38.5311 | no_improve = 84 | time = 15s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  200 | train‑avg =  37.9996 | soft‑eval =  38.3072 | best =  38.5311 | no_improve = 94 | time = 16s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  210 | train‑avg =  37.7425 | soft‑eval =  38.0597 | best =  38.5311 | no_improve = 104 | time = 17s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  220 | train‑avg =  38.2091 | soft‑eval =  37.9597 | best =  38.5311 | no_improve = 114 | time = 18s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  230 | train‑avg =  38.1606 | soft‑eval =  38.1315 | best =  38.5311 | no_improve = 124 | time = 19s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  240 | train‑avg =  37.9510 | soft‑eval =  38.6025 | best =  38.5311 | no_improve = 134 | time = 19s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  250 | train‑avg =  38.2169 | soft‑eval =  37.8244 | best =  38.7689 | no_improve =  6 | time = 20s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  260 | train‑avg =  37.9008 | soft‑eval =  37.7066 | best =  38.7689 | no_improve = 16 | time = 21s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  270 | train‑avg =  38.2069 | soft‑eval =  38.0403 | best =  38.7689 | no_improve = 26 | time = 22s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  280 | train‑avg =  38.2257 | soft‑eval =  37.8331 | best =  38.7689 | no_improve = 36 | time = 23s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  290 | train‑avg =  38.1389 | soft‑eval =  38.2147 | best =  38.7689 | no_improve = 46 | time = 24s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  300 | train‑avg =  38.0832 | soft‑eval =  38.3892 | best =  38.7689 | no_improve = 56 | time = 24s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  310 | train‑avg =  38.1010 | soft‑eval =  38.0001 | best =  38.7689 | no_improve = 66 | time = 25s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  320 | train‑avg =  38.1283 | soft‑eval =  38.5212 | best =  38.7689 | no_improve = 76 | time = 26s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  330 | train‑avg =  37.7768 | soft‑eval =  38.2357 | best =  38.7689 | no_improve = 86 | time = 27s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  340 | train‑avg =  38.0596 | soft‑eval =  37.8755 | best =  38.7689 | no_improve = 96 | time = 28s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  350 | train‑avg =  38.1107 | soft‑eval =  37.9809 | best =  38.7689 | no_improve = 106 | time = 29s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  360 | train‑avg =  38.1312 | soft‑eval =  38.0229 | best =  38.7689 | no_improve = 116 | time = 30s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  370 | train‑avg =  38.2193 | soft‑eval =  38.3599 | best =  38.7689 | no_improve = 126 | time = 31s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  380 | train‑avg =  38.4588 | soft‑eval =  37.7680 | best =  38.8948 | no_improve =  5 | time = 31s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  390 | train‑avg =  38.1637 | soft‑eval =  37.7926 | best =  38.8948 | no_improve = 15 | time = 32s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  400 | train‑avg =  38.0866 | soft‑eval =  37.8710 | best =  38.8948 | no_improve = 25 | time = 33s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 3.50e-03
# Epoch  410 | train‑avg =  38.0587 | soft‑eval =  38.2635 | best =  38.8948 | no_improve = 35 | time = 34s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 3.50e-03
# Epoch  420 | train‑avg =  38.1065 | soft‑eval =  37.9468 | best =  38.8948 | no_improve = 45 | time = 35s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 3.50e-03
# Epoch  430 | train‑avg =  38.6523 | soft‑eval =  38.1709 | best =  38.8948 | no_improve = 55 | time = 35s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 3.50e-03
# Epoch  440 | train‑avg =  38.2063 | soft‑eval =  38.4946 | best =  38.8948 | no_improve = 65 | time = 36s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 3.50e-03
# Epoch  450 | train‑avg =  38.3958 | soft‑eval =  38.1376 | best =  38.8948 | no_improve = 75 | time = 37s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 3.50e-03
# Epoch  460 | train‑avg =  37.9339 | soft‑eval =  38.4425 | best =  38.8948 | no_improve = 85 | time = 38s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 3.50e-03
# Epoch  470 | train‑avg =  38.1347 | soft‑eval =  38.0372 | best =  38.8948 | no_improve = 95 | time = 39s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 3.50e-03
# Epoch  480 | train‑avg =  38.0850 | soft‑eval =  38.0566 | best =  38.8948 | no_improve = 105 | time = 40s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 3.50e-03
# Epoch  490 | train‑avg =  37.9015 | soft‑eval =  38.1422 | best =  38.8948 | no_improve = 115 | time = 41s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 3.50e-03
# Epoch  500 | train‑avg =  37.9866 | soft‑eval =  38.5300 | best =  38.8948 | no_improve = 125 | time = 41s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 3.50e-03
# Epoch  510 | train‑avg =  38.0327 | soft‑eval =  37.6542 | best =  38.8948 | no_improve = 135 | time = 42s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 3.50e-03
# Epoch  520 | train‑avg =  37.9009 | soft‑eval =  38.4847 | best =  38.8948 | no_improve = 145 | time = 43s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 3.50e-03
# Epoch  530 | train‑avg =  38.5980 | soft‑eval =  38.6877 | best =  38.8948 | no_improve = 155 | time = 44s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 3.50e-03
# Epoch  540 | train‑avg =  38.3216 | soft‑eval =  38.2228 | best =  38.8948 | no_improve = 165 | time = 45s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 3.50e-03
# Epoch  550 | train‑avg =  37.8647 | soft‑eval =  38.3304 | best =  38.8948 | no_improve = 175 | time = 46s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 3.50e-03
# Epoch  560 | train‑avg =  37.9488 | soft‑eval =  38.1014 | best =  38.8948 | no_improve = 185 | time = 47s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 3.50e-03
# Epoch  570 | train‑avg =  38.2823 | soft‑eval =  37.9513 | best =  38.8948 | no_improve = 195 | time = 47s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 3.50e-03
# Early stopping triggered after 575 epochs (48s)
# Best score: 38.894791
# No improvement for 200 epochs
#
# Training completed after 574 epochs
# Total training time: 48s
# Average time per epoch: 0.1s
# Best evaluation score: 38.894791
# Final score: 38.135681
#
# Evaluating final policy...
# Sharp policy price ≈ 38.2119  CI: [38.1925,38.2313] (95% CI)
# Setting up input normalization...
# Starting training with early stopping (patience=200, min_epochs=50)
# Will stop when improvement < 1.00e-02 absolute or < 1.00e-03 relative
# Epoch   10 | train‑avg =  36.4241 | soft‑eval =  35.9456 | best =  35.8927 | no_improve =  1 | time = 0s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch   20 | train‑avg =  37.4957 | soft‑eval =  37.2800 | best =  37.5889 | no_improve =  0 | time = 1s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch   30 | train‑avg =  37.6139 | soft‑eval =  37.3375 | best =  38.0330 | no_improve =  1 | time = 2s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch   40 | train‑avg =  37.7036 | soft‑eval =  38.0918 | best =  38.0330 | no_improve = 11 | time = 3s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch   50 | train‑avg =  37.5299 | soft‑eval =  37.8858 | best =  38.3751 | no_improve =  3 | time = 4s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch   60 | train‑avg =  37.8537 | soft‑eval =  37.9433 | best =  38.3751 | no_improve = 13 | time = 5s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch   70 | train‑avg =  37.5926 | soft‑eval =  37.6617 | best =  38.3751 | no_improve = 23 | time = 5s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch   80 | train‑avg =  37.8938 | soft‑eval =  37.8076 | best =  38.3751 | no_improve = 33 | time = 6s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch   90 | train‑avg =  37.9782 | soft‑eval =  37.6762 | best =  38.3751 | no_improve = 43 | time = 7s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  100 | train‑avg =  38.0432 | soft‑eval =  38.0716 | best =  38.3751 | no_improve = 53 | time = 8s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  110 | train‑avg =  37.8662 | soft‑eval =  38.5225 | best =  38.3751 | no_improve = 63 | time = 9s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  120 | train‑avg =  38.0334 | soft‑eval =  37.8495 | best =  38.5225 | no_improve =  9 | time = 10s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  130 | train‑avg =  37.7180 | soft‑eval =  37.6678 | best =  38.5225 | no_improve = 19 | time = 11s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  140 | train‑avg =  38.3132 | soft‑eval =  37.9547 | best =  38.5225 | no_improve = 29 | time = 11s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  150 | train‑avg =  38.1574 | soft‑eval =  37.8490 | best =  38.5225 | no_improve = 39 | time = 12s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  160 | train‑avg =  38.0988 | soft‑eval =  38.2350 | best =  38.5225 | no_improve = 49 | time = 13s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  170 | train‑avg =  38.0042 | soft‑eval =  38.1756 | best =  38.5225 | no_improve = 59 | time = 14s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  180 | train‑avg =  38.2302 | soft‑eval =  37.7719 | best =  38.5225 | no_improve = 69 | time = 15s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  190 | train‑avg =  37.7169 | soft‑eval =  37.9655 | best =  38.5225 | no_improve = 79 | time = 16s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  200 | train‑avg =  37.6740 | soft‑eval =  38.2282 | best =  38.5225 | no_improve = 89 | time = 16s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  210 | train‑avg =  37.8252 | soft‑eval =  38.1541 | best =  38.5225 | no_improve = 99 | time = 17s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  220 | train‑avg =  37.9807 | soft‑eval =  38.0798 | best =  38.5225 | no_improve = 109 | time = 18s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  230 | train‑avg =  38.0073 | soft‑eval =  37.7732 | best =  38.5225 | no_improve = 119 | time = 19s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  240 | train‑avg =  38.0977 | soft‑eval =  38.1104 | best =  38.5225 | no_improve = 129 | time = 20s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  250 | train‑avg =  37.9217 | soft‑eval =  37.8364 | best =  38.5225 | no_improve = 139 | time = 21s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  260 | train‑avg =  38.4899 | soft‑eval =  38.1693 | best =  38.5225 | no_improve = 149 | time = 22s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 7.00e-03
# Epoch  270 | train‑avg =  37.9352 | soft‑eval =  37.8275 | best =  38.5225 | no_improve = 159 | time = 22s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 3.50e-03
# Epoch  280 | train‑avg =  38.2908 | soft‑eval =  38.1957 | best =  38.5225 | no_improve = 169 | time = 23s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 3.50e-03
# Epoch  290 | train‑avg =  38.3706 | soft‑eval =  38.0500 | best =  38.5225 | no_improve = 179 | time = 24s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 3.50e-03
# Epoch  300 | train‑avg =  38.2281 | soft‑eval =  38.1323 | best =  38.5225 | no_improve = 189 | time = 25s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 3.50e-03
# Epoch  310 | train‑avg =  38.3805 | soft‑eval =  37.9068 | best =  38.5225 | no_improve = 199 | time = 26s | epoch_time = 0.1s | soft_sigma = 2.000 | lr = 3.50e-03
# Early stopping triggered after 311 epochs (26s)
# Best score: 38.522465
# No improvement for 200 epochs
#
# Training completed after 310 epochs
# Total training time: 26s
# Average time per epoch: 0.1s
# Best evaluation score: 38.522465
# Final score: 37.906830
#
# Evaluating final policy...
# Sharp policy price ≈ 38.1654  CI: [38.1462,38.1846] (95% CI)

# %%
print(f"Price = {np.mean(prices):.3f} ({np.std(prices):.3f})")
print(f"Max Price = {np.max(prices):.3f}")
print(f"Times = {times}")
# Out:
# Price = 38.194 (0.030)
# Max Price = 38.242
# Times = ['31s', '45s', '36s', '36s', '41s', '57s', '48s', '26s']

# %%
times = ['31s', '45s', '36s', '36s', '41s', '57s', '48s', '26s']
print(f"Average training time = {average_time_in_seconds(times)}")
# Out:
# Average training time = 40.0
